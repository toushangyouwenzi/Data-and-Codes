# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/library/LSK.py
# /kaggle/input/newlsk/LSK.py
# /kaggle/input/all-province/all_province_data.xlsx

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torch_geometric) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.8 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
# %%writefile MLLA1D.py

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold


# 种子固定
np.random.seed(42)
torch.manual_seed(42)  # 设置 CPU 随机种子
torch.cuda.manual_seed(42)  # 设置 GPU 随机种子
torch.cuda.manual_seed_all(42)  # 如果使用多 GPU，设置所有 GPU 的随机种子
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# -------------------------
# 1. 环境及数据准备
# -------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

file_path = '/kaggle/input/all-province/all_province_data.xlsx'  # 请根据实际路径修改
data = pd.read_excel(file_path)

# 将时间列转换为年份（假设 '时间' 列格式可提取数字）
data['Year'] = data['时间'].str.extract('(\d+)').astype(int)

# 独热编码省份
data = pd.get_dummies(data, columns=['Province'])

# 选择特征
features = [
    'Year', 'Ammonia Nitrogen Emissions', 'Average Temperature', 
    'Average Years of Education per Capita', 'Chemical Oxygen Demand Emissions', 
    'Electricity Consumption', 'Geographic-Mean PM2', 
    'Government Expenditure on Environmental Protection', 
    'NOx Emissions', 'Number of Healthcare Institutions', 
    'Number of Healthcare Personnel', 'Oil Emissions', 
    'Per Capita Disposable Income', 'Resident Population', 
    'SO2 Emissions', 'Total Nitrogen Emissions', 
    'Total Phosphorus Emissions'
] + list(data.columns[data.columns.str.startswith('Province_')])

X = data[features]
y = data['Total CO2 emissions']

X = X.fillna(X.mean())

# -------------------------
# 2. 划分数据集
# -------------------------
# 将 2020, 2021, 2022 年的数据作为最终测试集，不参与交叉验证
X_test_2020 = X[X['Year'] == 2020]
X_test_2021 = X[X['Year'] == 2021]
X_test_2022 = X[X['Year'] == 2022]

y_test_2020 = y[X['Year'] == 2020]
y_test_2021 = y[X['Year'] == 2021]
y_test_2022 = y[X['Year'] == 2022]

# 其他年份作为训练集进行交叉验证（例如：<=2019）
X_train_all = X[~X['Year'].isin([2020, 2021, 2022])]
y_train_all = y[~X['Year'].isin([2020, 2021, 2022])]

# -------------------------
# 3. 定义模型
# -------------------------
class LSTMGraphSAGEModel(nn.Module):
    def __init__(self, num_node_features, hidden_dim, lstm_hidden_dim, out_dim, num_lstm_layers=2):
        super(LSTMGraphSAGEModel, self).__init__()
        
        # GraphSAGE layer
        self.conv1 = SAGEConv(num_node_features, hidden_dim)
        self.conv2 = SAGEConv(hidden_dim, hidden_dim)
        
        # LSTM layer
        self.lstm = nn.LSTM(input_size=num_node_features, hidden_size=lstm_hidden_dim, 
                            num_layers=num_lstm_layers, batch_first=True)
        
        # Fully connected layer for output
        self.fc = nn.Linear(hidden_dim + lstm_hidden_dim, out_dim)

    def forward(self, graph_data, lstm_input):
        # GraphSAGE part
        x, edge_index = graph_data.x, graph_data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        
        # LSTM part
        lstm_out, (hn, cn) = self.lstm(lstm_input)
        lstm_out = hn[-1]  # Use the last hidden state of the LSTM
        
        # Combine both GraphSAGE and LSTM outputs
        # 将 x.mean(dim=0) 扩展到与 batch_size 相同的维度
        x_expanded = x.mean(dim=0).unsqueeze(0).expand(lstm_out.size(0), -1)  # 使得 x_expanded 大小为 [batch_size, hidden_dim]
        combined = torch.cat([x_expanded, lstm_out], dim=-1)
        out = self.fc(combined)
        return out

# -------------------------
# 4. 定义构图函数
# -------------------------
def build_graph(x_array, threshold_percent=90):
    """
    根据给定的特征数组构建图，使用欧氏距离与指定百分位阈值构图。
    """
    distances = euclidean_distances(x_array)
    threshold = np.percentile(distances, threshold_percent)
    edge_index = np.array(np.where(distances < threshold))
    # 去除自环
    edge_index = edge_index[:, edge_index[0] != edge_index[1]]
    edge_index = torch.tensor(edge_index, dtype=torch.long)
    x_tensor = torch.tensor(x_array, dtype=torch.float)
    return Data(x=x_tensor, edge_index=edge_index)

# -------------------------
# 5. 五折交叉验证+早停+网格搜索
# -------------------------
candidate_learning_rates = [0.001, 0.005, 0.01]
candidate_patience_values = [10, 20, 30]
candidate_hidden_dims = [32, 64, 128]
candidate_lstm_hidden_dims = [32, 64, 128]

num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)
grid_search_results = []

print("\n====== Begin Grid Search ======")
for lr in candidate_learning_rates:
    for patience in candidate_patience_values:
        for hidden_dim in candidate_hidden_dims:
            for lstm_hidden_dim in candidate_lstm_hidden_dims:
                fold_r2_scores = []
                fold_best_epochs = []
                print(f"\nTesting combination: learning_rate={lr}, patience={patience}, hidden_dim={hidden_dim}, lstm_hidden_dim={lstm_hidden_dim}")
                for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_all)):
                    # 划分本折训练和验证数据
                    X_train_fold = X_train_all.iloc[train_idx].copy()
                    y_train_fold = y_train_all.iloc[train_idx].copy()
                    X_val_fold = X_train_all.iloc[val_idx].copy()
                    y_val_fold = y_train_all.iloc[val_idx].copy()
                    
                    scaler_x = MinMaxScaler()
                    X_train_fold_scaled = scaler_x.fit_transform(X_train_fold)
                    X_val_fold_scaled = scaler_x.transform(X_val_fold)
                    scaler_y = MinMaxScaler()
                    y_train_fold_scaled = scaler_y.fit_transform(y_train_fold.values.reshape(-1, 1)).ravel()
                    
                    train_data_fold = build_graph(X_train_fold_scaled).to(device)
                    val_data_fold = build_graph(X_val_fold_scaled).to(device)
                    y_train_fold_scaled_t = torch.tensor(y_train_fold_scaled, dtype=torch.float).to(device)
                    y_val_fold_t = torch.tensor(y_val_fold.values, dtype=torch.float).to(device)
                    
                    # Prepare LSTM input (time series features)
                    lstm_input_train = torch.tensor(X_train_fold_scaled.reshape(-1, 1, X_train_fold_scaled.shape[1]), dtype=torch.float).to(device)
                    lstm_input_val = torch.tensor(X_val_fold_scaled.reshape(-1, 1, X_val_fold_scaled.shape[1]), dtype=torch.float).to(device)

                    
                    model = LSTMGraphSAGEModel(num_node_features=X_train_fold_scaled.shape[1],
                                               hidden_dim=hidden_dim,
                                               lstm_hidden_dim=lstm_hidden_dim,
                                               out_dim=1).to(device)
                    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
                    criterion = torch.nn.MSELoss()
                    
                    best_val_r2 = float('-inf')
                    best_epoch = 0
                    no_improve_counter = 0
                    max_epochs = 1000
                    # max_epochs = 10
                    
                    for epoch in range(max_epochs):
                        model.train()
                        optimizer.zero_grad()
                        out = model(train_data_fold, lstm_input_train).squeeze()
                        loss = criterion(out, y_train_fold_scaled_t)
                        loss.backward()
                        optimizer.step()
                        
                        # 验证
                        model.eval()
                        with torch.no_grad():
                            preds_val = model(val_data_fold, lstm_input_val).squeeze().cpu().numpy()
                        preds_val_unscaled = scaler_y.inverse_transform(preds_val.reshape(-1, 1)).ravel()
                        val_r2 = r2_score(y_val_fold_t.cpu().numpy(), preds_val_unscaled)
                        
                        if val_r2 > best_val_r2:
                            best_val_r2 = val_r2
                            best_epoch = epoch + 1
                            no_improve_counter = 0
                        else:
                            no_improve_counter += 1
                        if no_improve_counter >= patience:
                            print(f"Fold {fold+1}: Early stopping at epoch {epoch+1} (patience={patience})")
                            break
                    fold_r2_scores.append(best_val_r2)
                    fold_best_epochs.append(best_epoch)
                    print(f"Fold {fold+1}: Best Epoch = {best_epoch}, Val_R² = {best_val_r2:.4f}")
            
            avg_r2 = np.mean(fold_r2_scores)
            avg_best_epoch = np.mean(fold_best_epochs)
            print(f"Combination lr={lr}, patience={patience}, hidden_dim={hidden_dim}, lstm_hidden_dim={lstm_hidden_dim}: Avg Val_R² = {avg_r2:.4f}, Avg Best Epoch = {avg_best_epoch:.2f}")
            grid_search_results.append({
                'learning_rate': lr,
                'patience': patience,
                'hidden_dim': hidden_dim,
                'lstm_hidden_dim': lstm_hidden_dim,
                'avg_val_r2': avg_r2,
                'avg_best_epoch': avg_best_epoch
            })

# 选择最佳超参数组合
best_combo = max(grid_search_results, key=lambda x: x['avg_val_r2'])
best_learning_rate = best_combo['learning_rate']
best_patience = best_combo['patience']
best_hidden_dim = best_combo['hidden_dim']
best_lstm_hidden_dim = best_combo['lstm_hidden_dim']
final_num_epochs = int(best_combo['avg_best_epoch'])  # 使用平均 best epoch 作为最终训练轮次

print("\n====== Grid Search Completed ======")
print("Best hyperparameters from grid search:")
print(best_combo)
print(f"Final training epochs set to: {final_num_epochs}")
# Out:
# Using device: cuda
#
# ====== Begin Grid Search ======
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 39 (patience=10)
# Fold 1: Best Epoch = 29, Val_R² = 0.0407
# Fold 2: Early stopping at epoch 36 (patience=10)
# Fold 2: Best Epoch = 26, Val_R² = 0.0220
# Fold 3: Early stopping at epoch 29 (patience=10)
# Fold 3: Best Epoch = 19, Val_R² = 0.0139
# Fold 4: Early stopping at epoch 30 (patience=10)
# Fold 4: Best Epoch = 20, Val_R² = 0.0306
# Fold 5: Early stopping at epoch 26 (patience=10)
# Fold 5: Best Epoch = 16, Val_R² = 0.0263
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 35 (patience=10)
# Fold 1: Best Epoch = 25, Val_R² = 0.0911
# Fold 2: Early stopping at epoch 259 (patience=10)
# Fold 2: Best Epoch = 249, Val_R² = 0.9761
# Fold 3: Early stopping at epoch 33 (patience=10)
# Fold 3: Best Epoch = 23, Val_R² = 0.0905
# Fold 4: Early stopping at epoch 31 (patience=10)
# Fold 4: Best Epoch = 21, Val_R² = 0.0664
# Fold 5: Early stopping at epoch 31 (patience=10)
# Fold 5: Best Epoch = 21, Val_R² = 0.0945
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 39 (patience=10)
# Fold 1: Best Epoch = 29, Val_R² = 0.2979
# Fold 2: Early stopping at epoch 221 (patience=10)
# Fold 2: Best Epoch = 211, Val_R² = 0.9767
# Fold 3: Early stopping at epoch 356 (patience=10)
# Fold 3: Best Epoch = 346, Val_R² = 0.9638
# Fold 4: Early stopping at epoch 27 (patience=10)
# Fold 4: Best Epoch = 17, Val_R² = 0.1340
# Fold 5: Early stopping at epoch 29 (patience=10)
# Fold 5: Best Epoch = 19, Val_R² = 0.1275
# Combination lr=0.001, patience=10, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.5000, Avg Best Epoch = 124.40
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 31 (patience=10)
# Fold 1: Best Epoch = 21, Val_R² = 0.0275
# Fold 2: Early stopping at epoch 18 (patience=10)
# Fold 2: Best Epoch = 8, Val_R² = 0.0182
# Fold 3: Early stopping at epoch 36 (patience=10)
# Fold 3: Best Epoch = 26, Val_R² = 0.0380
# Fold 4: Early stopping at epoch 21 (patience=10)
# Fold 4: Best Epoch = 11, Val_R² = 0.0048
# Fold 5: Early stopping at epoch 21 (patience=10)
# Fold 5: Best Epoch = 11, Val_R² = 0.0170
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 32 (patience=10)
# Fold 1: Best Epoch = 22, Val_R² = 0.0670
# Fold 2: Early stopping at epoch 20 (patience=10)
# Fold 2: Best Epoch = 10, Val_R² = 0.0302
# Fold 3: Early stopping at epoch 362 (patience=10)
# Fold 3: Best Epoch = 352, Val_R² = 0.9636
# Fold 4: Early stopping at epoch 22 (patience=10)
# Fold 4: Best Epoch = 12, Val_R² = 0.0278
# Fold 5: Early stopping at epoch 17 (patience=10)
# Fold 5: Best Epoch = 7, Val_R² = 0.0190
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 30 (patience=10)
# Fold 1: Best Epoch = 20, Val_R² = 0.1647
# Fold 2: Early stopping at epoch 216 (patience=10)
# Fold 2: Best Epoch = 206, Val_R² = 0.9760
# Fold 3: Early stopping at epoch 133 (patience=10)
# Fold 3: Best Epoch = 123, Val_R² = 0.9567
# Fold 4: Early stopping at epoch 20 (patience=10)
# Fold 4: Best Epoch = 10, Val_R² = 0.0542
# Fold 5: Early stopping at epoch 18 (patience=10)
# Fold 5: Best Epoch = 8, Val_R² = 0.0376
# Combination lr=0.001, patience=10, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.4378, Avg Best Epoch = 73.40
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 21 (patience=10)
# Fold 1: Best Epoch = 11, Val_R² = 0.0039
# Fold 2: Early stopping at epoch 24 (patience=10)
# Fold 2: Best Epoch = 14, Val_R² = 0.0070
# Fold 3: Early stopping at epoch 27 (patience=10)
# Fold 3: Best Epoch = 17, Val_R² = 0.0026
# Fold 4: Early stopping at epoch 34 (patience=10)
# Fold 4: Best Epoch = 24, Val_R² = 0.0193
# Fold 5: Early stopping at epoch 15 (patience=10)
# Fold 5: Best Epoch = 5, Val_R² = 0.0076
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 22 (patience=10)
# Fold 1: Best Epoch = 12, Val_R² = 0.0187
# Fold 2: Early stopping at epoch 245 (patience=10)
# Fold 2: Best Epoch = 235, Val_R² = 0.9761
# Fold 3: Early stopping at epoch 343 (patience=10)
# Fold 3: Best Epoch = 333, Val_R² = 0.9631
# Fold 4: Early stopping at epoch 356 (patience=10)
# Fold 4: Best Epoch = 346, Val_R² = 0.9629
# Fold 5: Early stopping at epoch 295 (patience=10)
# Fold 5: Best Epoch = 285, Val_R² = 0.9815
#
# Testing combination: learning_rate=0.001, patience=10, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 26 (patience=10)
# Fold 1: Best Epoch = 16, Val_R² = 0.0674
# Fold 2: Early stopping at epoch 210 (patience=10)
# Fold 2: Best Epoch = 200, Val_R² = 0.9760
# Fold 3: Early stopping at epoch 126 (patience=10)
# Fold 3: Best Epoch = 116, Val_R² = 0.9576
# Fold 4: Early stopping at epoch 331 (patience=10)
# Fold 4: Best Epoch = 321, Val_R² = 0.9625
# Fold 5: Early stopping at epoch 271 (patience=10)
# Fold 5: Best Epoch = 261, Val_R² = 0.9823
# Combination lr=0.001, patience=10, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.7892, Avg Best Epoch = 182.80
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 51 (patience=20)
# Fold 1: Best Epoch = 31, Val_R² = 0.0698
# Fold 2: Early stopping at epoch 269 (patience=20)
# Fold 2: Best Epoch = 249, Val_R² = 0.9757
# Fold 3: Early stopping at epoch 500 (patience=20)
# Fold 3: Best Epoch = 480, Val_R² = 0.9619
# Fold 4: Early stopping at epoch 465 (patience=20)
# Fold 4: Best Epoch = 445, Val_R² = 0.9624
# Fold 5: Early stopping at epoch 179 (patience=20)
# Fold 5: Best Epoch = 159, Val_R² = 0.9795
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 145 (patience=20)
# Fold 1: Best Epoch = 125, Val_R² = 0.9707
# Fold 2: Early stopping at epoch 244 (patience=20)
# Fold 2: Best Epoch = 224, Val_R² = 0.9768
# Fold 3: Early stopping at epoch 416 (patience=20)
# Fold 3: Best Epoch = 396, Val_R² = 0.9636
# Fold 4: Early stopping at epoch 405 (patience=20)
# Fold 4: Best Epoch = 385, Val_R² = 0.9630
# Fold 5: Early stopping at epoch 324 (patience=20)
# Fold 5: Best Epoch = 304, Val_R² = 0.9820
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 121 (patience=20)
# Fold 1: Best Epoch = 101, Val_R² = 0.9711
# Fold 2: Early stopping at epoch 243 (patience=20)
# Fold 2: Best Epoch = 223, Val_R² = 0.9763
# Fold 3: Early stopping at epoch 405 (patience=20)
# Fold 3: Best Epoch = 385, Val_R² = 0.9656
# Fold 4: Early stopping at epoch 450 (patience=20)
# Fold 4: Best Epoch = 430, Val_R² = 0.9627
# Fold 5: Early stopping at epoch 303 (patience=20)
# Fold 5: Best Epoch = 283, Val_R² = 0.9825
# Combination lr=0.001, patience=20, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9716, Avg Best Epoch = 284.40
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 36 (patience=20)
# Fold 1: Best Epoch = 16, Val_R² = 0.0110
# Fold 2: Early stopping at epoch 308 (patience=20)
# Fold 2: Best Epoch = 288, Val_R² = 0.9753
# Fold 3: Early stopping at epoch 478 (patience=20)
# Fold 3: Best Epoch = 458, Val_R² = 0.9633
# Fold 4: Early stopping at epoch 473 (patience=20)
# Fold 4: Best Epoch = 453, Val_R² = 0.9631
# Fold 5: Early stopping at epoch 321 (patience=20)
# Fold 5: Best Epoch = 301, Val_R² = 0.9803
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 141 (patience=20)
# Fold 1: Best Epoch = 121, Val_R² = 0.9681
# Fold 2: Early stopping at epoch 231 (patience=20)
# Fold 2: Best Epoch = 211, Val_R² = 0.9759
# Fold 3: Early stopping at epoch 424 (patience=20)
# Fold 3: Best Epoch = 404, Val_R² = 0.9617
# Fold 4: Early stopping at epoch 398 (patience=20)
# Fold 4: Best Epoch = 378, Val_R² = 0.9620
# Fold 5: Early stopping at epoch 329 (patience=20)
# Fold 5: Best Epoch = 309, Val_R² = 0.9815
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 121 (patience=20)
# Fold 1: Best Epoch = 101, Val_R² = 0.9713
# Fold 2: Early stopping at epoch 228 (patience=20)
# Fold 2: Best Epoch = 208, Val_R² = 0.9762
# Fold 3: Early stopping at epoch 368 (patience=20)
# Fold 3: Best Epoch = 348, Val_R² = 0.9642
# Fold 4: Early stopping at epoch 394 (patience=20)
# Fold 4: Best Epoch = 374, Val_R² = 0.9627
# Fold 5: Early stopping at epoch 298 (patience=20)
# Fold 5: Best Epoch = 278, Val_R² = 0.9820
# Combination lr=0.001, patience=20, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9713, Avg Best Epoch = 261.80
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 294 (patience=20)
# Fold 1: Best Epoch = 274, Val_R² = 0.9706
# Fold 2: Early stopping at epoch 282 (patience=20)
# Fold 2: Best Epoch = 262, Val_R² = 0.9750
# Fold 3: Early stopping at epoch 160 (patience=20)
# Fold 3: Best Epoch = 140, Val_R² = 0.9515
# Fold 4: Early stopping at epoch 399 (patience=20)
# Fold 4: Best Epoch = 379, Val_R² = 0.9637
# Fold 5: Early stopping at epoch 327 (patience=20)
# Fold 5: Best Epoch = 307, Val_R² = 0.9815
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 132 (patience=20)
# Fold 1: Best Epoch = 112, Val_R² = 0.9692
# Fold 2: Early stopping at epoch 245 (patience=20)
# Fold 2: Best Epoch = 225, Val_R² = 0.9764
# Fold 3: Early stopping at epoch 363 (patience=20)
# Fold 3: Best Epoch = 343, Val_R² = 0.9629
# Fold 4: Early stopping at epoch 375 (patience=20)
# Fold 4: Best Epoch = 355, Val_R² = 0.9621
# Fold 5: Early stopping at epoch 314 (patience=20)
# Fold 5: Best Epoch = 294, Val_R² = 0.9806
#
# Testing combination: learning_rate=0.001, patience=20, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 117 (patience=20)
# Fold 1: Best Epoch = 97, Val_R² = 0.9704
# Fold 2: Early stopping at epoch 213 (patience=20)
# Fold 2: Best Epoch = 193, Val_R² = 0.9756
# Fold 3: Early stopping at epoch 361 (patience=20)
# Fold 3: Best Epoch = 341, Val_R² = 0.9637
# Fold 4: Early stopping at epoch 356 (patience=20)
# Fold 4: Best Epoch = 336, Val_R² = 0.9629
# Fold 5: Early stopping at epoch 270 (patience=20)
# Fold 5: Best Epoch = 250, Val_R² = 0.9817
# Combination lr=0.001, patience=20, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9709, Avg Best Epoch = 243.40
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 312 (patience=30)
# Fold 1: Best Epoch = 282, Val_R² = 0.9674
# Fold 2: Early stopping at epoch 325 (patience=30)
# Fold 2: Best Epoch = 295, Val_R² = 0.9759
# Fold 3: Early stopping at epoch 477 (patience=30)
# Fold 3: Best Epoch = 447, Val_R² = 0.9622
# Fold 4: Early stopping at epoch 558 (patience=30)
# Fold 4: Best Epoch = 528, Val_R² = 0.9622
# Fold 5: Early stopping at epoch 371 (patience=30)
# Fold 5: Best Epoch = 341, Val_R² = 0.9819
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 158 (patience=30)
# Fold 1: Best Epoch = 128, Val_R² = 0.9689
# Fold 2: Early stopping at epoch 272 (patience=30)
# Fold 2: Best Epoch = 242, Val_R² = 0.9757
# Fold 3: Early stopping at epoch 414 (patience=30)
# Fold 3: Best Epoch = 384, Val_R² = 0.9633
# Fold 4: Early stopping at epoch 443 (patience=30)
# Fold 4: Best Epoch = 413, Val_R² = 0.9629
# Fold 5: Early stopping at epoch 302 (patience=30)
# Fold 5: Best Epoch = 272, Val_R² = 0.9814
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 145 (patience=30)
# Fold 1: Best Epoch = 115, Val_R² = 0.9690
# Fold 2: Early stopping at epoch 260 (patience=30)
# Fold 2: Best Epoch = 230, Val_R² = 0.9757
# Fold 3: Early stopping at epoch 381 (patience=30)
# Fold 3: Best Epoch = 351, Val_R² = 0.9647
# Fold 4: Early stopping at epoch 472 (patience=30)
# Fold 4: Best Epoch = 442, Val_R² = 0.9625
# Fold 5: Early stopping at epoch 320 (patience=30)
# Fold 5: Best Epoch = 290, Val_R² = 0.9825
# Combination lr=0.001, patience=30, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9709, Avg Best Epoch = 285.60
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 313 (patience=30)
# Fold 1: Best Epoch = 283, Val_R² = 0.9700
# Fold 2: Early stopping at epoch 302 (patience=30)
# Fold 2: Best Epoch = 272, Val_R² = 0.9741
# Fold 3: Early stopping at epoch 461 (patience=30)
# Fold 3: Best Epoch = 431, Val_R² = 0.9631
# Fold 4: Early stopping at epoch 449 (patience=30)
# Fold 4: Best Epoch = 419, Val_R² = 0.9628
# Fold 5: Early stopping at epoch 353 (patience=30)
# Fold 5: Best Epoch = 323, Val_R² = 0.9822
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 144 (patience=30)
# Fold 1: Best Epoch = 114, Val_R² = 0.9706
# Fold 2: Early stopping at epoch 258 (patience=30)
# Fold 2: Best Epoch = 228, Val_R² = 0.9762
# Fold 3: Early stopping at epoch 414 (patience=30)
# Fold 3: Best Epoch = 384, Val_R² = 0.9628
# Fold 4: Early stopping at epoch 397 (patience=30)
# Fold 4: Best Epoch = 367, Val_R² = 0.9620
# Fold 5: Early stopping at epoch 338 (patience=30)
# Fold 5: Best Epoch = 308, Val_R² = 0.9824
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 132 (patience=30)
# Fold 1: Best Epoch = 102, Val_R² = 0.9711
# Fold 2: Early stopping at epoch 235 (patience=30)
# Fold 2: Best Epoch = 205, Val_R² = 0.9763
# Fold 3: Early stopping at epoch 385 (patience=30)
# Fold 3: Best Epoch = 355, Val_R² = 0.9648
# Fold 4: Early stopping at epoch 392 (patience=30)
# Fold 4: Best Epoch = 362, Val_R² = 0.9635
# Fold 5: Early stopping at epoch 308 (patience=30)
# Fold 5: Best Epoch = 278, Val_R² = 0.9820
# Combination lr=0.001, patience=30, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9715, Avg Best Epoch = 260.40
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 293 (patience=30)
# Fold 1: Best Epoch = 263, Val_R² = 0.9702
# Fold 2: Early stopping at epoch 281 (patience=30)
# Fold 2: Best Epoch = 251, Val_R² = 0.9757
# Fold 3: Early stopping at epoch 421 (patience=30)
# Fold 3: Best Epoch = 391, Val_R² = 0.9628
# Fold 4: Early stopping at epoch 446 (patience=30)
# Fold 4: Best Epoch = 416, Val_R² = 0.9618
# Fold 5: Early stopping at epoch 300 (patience=30)
# Fold 5: Best Epoch = 270, Val_R² = 0.9805
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 269 (patience=30)
# Fold 1: Best Epoch = 239, Val_R² = 0.9698
# Fold 2: Early stopping at epoch 255 (patience=30)
# Fold 2: Best Epoch = 225, Val_R² = 0.9749
# Fold 3: Early stopping at epoch 377 (patience=30)
# Fold 3: Best Epoch = 347, Val_R² = 0.9629
# Fold 4: Early stopping at epoch 347 (patience=30)
# Fold 4: Best Epoch = 317, Val_R² = 0.9610
# Fold 5: Early stopping at epoch 309 (patience=30)
# Fold 5: Best Epoch = 279, Val_R² = 0.9809
#
# Testing combination: learning_rate=0.001, patience=30, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 123 (patience=30)
# Fold 1: Best Epoch = 93, Val_R² = 0.9699
# Fold 2: Early stopping at epoch 221 (patience=30)
# Fold 2: Best Epoch = 191, Val_R² = 0.9759
# Fold 3: Early stopping at epoch 358 (patience=30)
# Fold 3: Best Epoch = 328, Val_R² = 0.9638
# Fold 4: Early stopping at epoch 332 (patience=30)
# Fold 4: Best Epoch = 302, Val_R² = 0.9626
# Fold 5: Early stopping at epoch 270 (patience=30)
# Fold 5: Best Epoch = 240, Val_R² = 0.9819
# Combination lr=0.001, patience=30, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9708, Avg Best Epoch = 230.80
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 77 (patience=10)
# Fold 1: Best Epoch = 67, Val_R² = 0.9697
# Fold 2: Early stopping at epoch 63 (patience=10)
# Fold 2: Best Epoch = 53, Val_R² = 0.9675
# Fold 3: Early stopping at epoch 106 (patience=10)
# Fold 3: Best Epoch = 96, Val_R² = 0.9616
# Fold 4: Early stopping at epoch 63 (patience=10)
# Fold 4: Best Epoch = 53, Val_R² = 0.9500
# Fold 5: Early stopping at epoch 64 (patience=10)
# Fold 5: Best Epoch = 54, Val_R² = 0.9743
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 67 (patience=10)
# Fold 1: Best Epoch = 57, Val_R² = 0.9699
# Fold 2: Early stopping at epoch 55 (patience=10)
# Fold 2: Best Epoch = 45, Val_R² = 0.9712
# Fold 3: Early stopping at epoch 89 (patience=10)
# Fold 3: Best Epoch = 79, Val_R² = 0.9634
# Fold 4: Early stopping at epoch 57 (patience=10)
# Fold 4: Best Epoch = 47, Val_R² = 0.9474
# Fold 5: Early stopping at epoch 53 (patience=10)
# Fold 5: Best Epoch = 43, Val_R² = 0.9753
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 60 (patience=10)
# Fold 1: Best Epoch = 50, Val_R² = 0.9695
# Fold 2: Early stopping at epoch 46 (patience=10)
# Fold 2: Best Epoch = 36, Val_R² = 0.9704
# Fold 3: Early stopping at epoch 93 (patience=10)
# Fold 3: Best Epoch = 83, Val_R² = 0.9636
# Fold 4: Early stopping at epoch 54 (patience=10)
# Fold 4: Best Epoch = 44, Val_R² = 0.9522
# Fold 5: Early stopping at epoch 48 (patience=10)
# Fold 5: Best Epoch = 38, Val_R² = 0.9783
# Combination lr=0.005, patience=10, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9668, Avg Best Epoch = 50.20
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 56 (patience=10)
# Fold 1: Best Epoch = 46, Val_R² = 0.9638
# Fold 2: Early stopping at epoch 114 (patience=10)
# Fold 2: Best Epoch = 104, Val_R² = 0.9758
# Fold 3: Early stopping at epoch 96 (patience=10)
# Fold 3: Best Epoch = 86, Val_R² = 0.9601
# Fold 4: Early stopping at epoch 44 (patience=10)
# Fold 4: Best Epoch = 34, Val_R² = 0.8860
# Fold 5: Early stopping at epoch 62 (patience=10)
# Fold 5: Best Epoch = 52, Val_R² = 0.9783
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 47 (patience=10)
# Fold 1: Best Epoch = 37, Val_R² = 0.9645
# Fold 2: Early stopping at epoch 50 (patience=10)
# Fold 2: Best Epoch = 40, Val_R² = 0.9660
# Fold 3: Early stopping at epoch 87 (patience=10)
# Fold 3: Best Epoch = 77, Val_R² = 0.9627
# Fold 4: Early stopping at epoch 55 (patience=10)
# Fold 4: Best Epoch = 45, Val_R² = 0.9537
# Fold 5: Early stopping at epoch 50 (patience=10)
# Fold 5: Best Epoch = 40, Val_R² = 0.9759
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 58 (patience=10)
# Fold 1: Best Epoch = 48, Val_R² = 0.9682
# Fold 2: Early stopping at epoch 93 (patience=10)
# Fold 2: Best Epoch = 83, Val_R² = 0.9759
# Fold 3: Early stopping at epoch 92 (patience=10)
# Fold 3: Best Epoch = 82, Val_R² = 0.9637
# Fold 4: Early stopping at epoch 45 (patience=10)
# Fold 4: Best Epoch = 35, Val_R² = 0.9530
# Fold 5: Early stopping at epoch 47 (patience=10)
# Fold 5: Best Epoch = 37, Val_R² = 0.9721
# Combination lr=0.005, patience=10, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9666, Avg Best Epoch = 57.00
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 64 (patience=10)
# Fold 1: Best Epoch = 54, Val_R² = 0.9601
# Fold 2: Early stopping at epoch 56 (patience=10)
# Fold 2: Best Epoch = 46, Val_R² = 0.9711
# Fold 3: Early stopping at epoch 63 (patience=10)
# Fold 3: Best Epoch = 53, Val_R² = 0.9548
# Fold 4: Early stopping at epoch 57 (patience=10)
# Fold 4: Best Epoch = 47, Val_R² = 0.9471
# Fold 5: Early stopping at epoch 56 (patience=10)
# Fold 5: Best Epoch = 46, Val_R² = 0.9677
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 57 (patience=10)
# Fold 1: Best Epoch = 47, Val_R² = 0.9633
# Fold 2: Early stopping at epoch 50 (patience=10)
# Fold 2: Best Epoch = 40, Val_R² = 0.9665
# Fold 3: Early stopping at epoch 51 (patience=10)
# Fold 3: Best Epoch = 41, Val_R² = 0.9479
# Fold 4: Early stopping at epoch 37 (patience=10)
# Fold 4: Best Epoch = 27, Val_R² = 0.9125
# Fold 5: Early stopping at epoch 53 (patience=10)
# Fold 5: Best Epoch = 43, Val_R² = 0.9750
#
# Testing combination: learning_rate=0.005, patience=10, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 45 (patience=10)
# Fold 1: Best Epoch = 35, Val_R² = 0.9610
# Fold 2: Early stopping at epoch 89 (patience=10)
# Fold 2: Best Epoch = 79, Val_R² = 0.9750
# Fold 3: Early stopping at epoch 42 (patience=10)
# Fold 3: Best Epoch = 32, Val_R² = 0.9471
# Fold 4: Early stopping at epoch 48 (patience=10)
# Fold 4: Best Epoch = 38, Val_R² = 0.9515
# Fold 5: Early stopping at epoch 70 (patience=10)
# Fold 5: Best Epoch = 60, Val_R² = 0.9805
# Combination lr=0.005, patience=10, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9630, Avg Best Epoch = 48.80
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 90 (patience=20)
# Fold 1: Best Epoch = 70, Val_R² = 0.9703
# Fold 2: Early stopping at epoch 122 (patience=20)
# Fold 2: Best Epoch = 102, Val_R² = 0.9760
# Fold 3: Early stopping at epoch 239 (patience=20)
# Fold 3: Best Epoch = 219, Val_R² = 0.9630
# Fold 4: Early stopping at epoch 104 (patience=20)
# Fold 4: Best Epoch = 84, Val_R² = 0.9644
# Fold 5: Early stopping at epoch 109 (patience=20)
# Fold 5: Best Epoch = 89, Val_R² = 0.9817
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 79 (patience=20)
# Fold 1: Best Epoch = 59, Val_R² = 0.9691
# Fold 2: Early stopping at epoch 120 (patience=20)
# Fold 2: Best Epoch = 100, Val_R² = 0.9762
# Fold 3: Early stopping at epoch 102 (patience=20)
# Fold 3: Best Epoch = 82, Val_R² = 0.9627
# Fold 4: Early stopping at epoch 94 (patience=20)
# Fold 4: Best Epoch = 74, Val_R² = 0.9637
# Fold 5: Early stopping at epoch 101 (patience=20)
# Fold 5: Best Epoch = 81, Val_R² = 0.9812
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 74 (patience=20)
# Fold 1: Best Epoch = 54, Val_R² = 0.9689
# Fold 2: Early stopping at epoch 94 (patience=20)
# Fold 2: Best Epoch = 74, Val_R² = 0.9751
# Fold 3: Early stopping at epoch 96 (patience=20)
# Fold 3: Best Epoch = 76, Val_R² = 0.9640
# Fold 4: Early stopping at epoch 58 (patience=20)
# Fold 4: Best Epoch = 38, Val_R² = 0.9549
# Fold 5: Early stopping at epoch 84 (patience=20)
# Fold 5: Best Epoch = 64, Val_R² = 0.9827
# Combination lr=0.005, patience=20, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9691, Avg Best Epoch = 61.20
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 105 (patience=20)
# Fold 1: Best Epoch = 85, Val_R² = 0.9710
# Fold 2: Early stopping at epoch 128 (patience=20)
# Fold 2: Best Epoch = 108, Val_R² = 0.9765
# Fold 3: Early stopping at epoch 203 (patience=20)
# Fold 3: Best Epoch = 183, Val_R² = 0.9634
# Fold 4: Early stopping at epoch 68 (patience=20)
# Fold 4: Best Epoch = 48, Val_R² = 0.9503
# Fold 5: Early stopping at epoch 162 (patience=20)
# Fold 5: Best Epoch = 142, Val_R² = 0.9812
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 82 (patience=20)
# Fold 1: Best Epoch = 62, Val_R² = 0.9700
# Fold 2: Early stopping at epoch 110 (patience=20)
# Fold 2: Best Epoch = 90, Val_R² = 0.9766
# Fold 3: Early stopping at epoch 97 (patience=20)
# Fold 3: Best Epoch = 77, Val_R² = 0.9614
# Fold 4: Early stopping at epoch 66 (patience=20)
# Fold 4: Best Epoch = 46, Val_R² = 0.9521
# Fold 5: Early stopping at epoch 89 (patience=20)
# Fold 5: Best Epoch = 69, Val_R² = 0.9805
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 119 (patience=20)
# Fold 1: Best Epoch = 99, Val_R² = 0.9697
# Fold 2: Early stopping at epoch 101 (patience=20)
# Fold 2: Best Epoch = 81, Val_R² = 0.9755
# Fold 3: Early stopping at epoch 97 (patience=20)
# Fold 3: Best Epoch = 77, Val_R² = 0.9644
# Fold 4: Early stopping at epoch 85 (patience=20)
# Fold 4: Best Epoch = 65, Val_R² = 0.9642
# Fold 5: Early stopping at epoch 79 (patience=20)
# Fold 5: Best Epoch = 59, Val_R² = 0.9811
# Combination lr=0.005, patience=20, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9710, Avg Best Epoch = 76.20
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 87 (patience=20)
# Fold 1: Best Epoch = 67, Val_R² = 0.9663
# Fold 2: Early stopping at epoch 123 (patience=20)
# Fold 2: Best Epoch = 103, Val_R² = 0.9761
# Fold 3: Early stopping at epoch 100 (patience=20)
# Fold 3: Best Epoch = 80, Val_R² = 0.9600
# Fold 4: Early stopping at epoch 70 (patience=20)
# Fold 4: Best Epoch = 50, Val_R² = 0.9492
# Fold 5: Early stopping at epoch 190 (patience=20)
# Fold 5: Best Epoch = 170, Val_R² = 0.9802
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 70 (patience=20)
# Fold 1: Best Epoch = 50, Val_R² = 0.9667
# Fold 2: Early stopping at epoch 58 (patience=20)
# Fold 2: Best Epoch = 38, Val_R² = 0.9700
# Fold 3: Early stopping at epoch 111 (patience=20)
# Fold 3: Best Epoch = 91, Val_R² = 0.9624
# Fold 4: Early stopping at epoch 97 (patience=20)
# Fold 4: Best Epoch = 77, Val_R² = 0.9637
# Fold 5: Early stopping at epoch 145 (patience=20)
# Fold 5: Best Epoch = 125, Val_R² = 0.9816
#
# Testing combination: learning_rate=0.005, patience=20, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 67 (patience=20)
# Fold 1: Best Epoch = 47, Val_R² = 0.9670
# Fold 2: Early stopping at epoch 107 (patience=20)
# Fold 2: Best Epoch = 87, Val_R² = 0.9746
# Fold 3: Early stopping at epoch 192 (patience=20)
# Fold 3: Best Epoch = 172, Val_R² = 0.9653
# Fold 4: Early stopping at epoch 52 (patience=20)
# Fold 4: Best Epoch = 32, Val_R² = 0.9492
# Fold 5: Early stopping at epoch 78 (patience=20)
# Fold 5: Best Epoch = 58, Val_R² = 0.9805
# Combination lr=0.005, patience=20, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9673, Avg Best Epoch = 79.20
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 133 (patience=30)
# Fold 1: Best Epoch = 103, Val_R² = 0.9697
# Fold 2: Early stopping at epoch 143 (patience=30)
# Fold 2: Best Epoch = 113, Val_R² = 0.9758
# Fold 3: Early stopping at epoch 204 (patience=30)
# Fold 3: Best Epoch = 174, Val_R² = 0.9634
# Fold 4: Early stopping at epoch 126 (patience=30)
# Fold 4: Best Epoch = 96, Val_R² = 0.9635
# Fold 5: Early stopping at epoch 159 (patience=30)
# Fold 5: Best Epoch = 129, Val_R² = 0.9802
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 98 (patience=30)
# Fold 1: Best Epoch = 68, Val_R² = 0.9693
# Fold 2: Early stopping at epoch 140 (patience=30)
# Fold 2: Best Epoch = 110, Val_R² = 0.9747
# Fold 3: Early stopping at epoch 219 (patience=30)
# Fold 3: Best Epoch = 189, Val_R² = 0.9643
# Fold 4: Early stopping at epoch 209 (patience=30)
# Fold 4: Best Epoch = 179, Val_R² = 0.9645
# Fold 5: Early stopping at epoch 180 (patience=30)
# Fold 5: Best Epoch = 150, Val_R² = 0.9808
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 144 (patience=30)
# Fold 1: Best Epoch = 114, Val_R² = 0.9699
# Fold 2: Early stopping at epoch 118 (patience=30)
# Fold 2: Best Epoch = 88, Val_R² = 0.9747
# Fold 3: Early stopping at epoch 215 (patience=30)
# Fold 3: Best Epoch = 185, Val_R² = 0.9662
# Fold 4: Early stopping at epoch 113 (patience=30)
# Fold 4: Best Epoch = 83, Val_R² = 0.9634
# Fold 5: Early stopping at epoch 101 (patience=30)
# Fold 5: Best Epoch = 71, Val_R² = 0.9814
# Combination lr=0.005, patience=30, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9711, Avg Best Epoch = 108.20
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 154 (patience=30)
# Fold 1: Best Epoch = 124, Val_R² = 0.9693
# Fold 2: Early stopping at epoch 136 (patience=30)
# Fold 2: Best Epoch = 106, Val_R² = 0.9758
# Fold 3: Early stopping at epoch 218 (patience=30)
# Fold 3: Best Epoch = 188, Val_R² = 0.9627
# Fold 4: Early stopping at epoch 108 (patience=30)
# Fold 4: Best Epoch = 78, Val_R² = 0.9653
# Fold 5: Early stopping at epoch 175 (patience=30)
# Fold 5: Best Epoch = 145, Val_R² = 0.9811
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 88 (patience=30)
# Fold 1: Best Epoch = 58, Val_R² = 0.9707
# Fold 2: Early stopping at epoch 113 (patience=30)
# Fold 2: Best Epoch = 83, Val_R² = 0.9759
# Fold 3: Early stopping at epoch 200 (patience=30)
# Fold 3: Best Epoch = 170, Val_R² = 0.9645
# Fold 4: Early stopping at epoch 104 (patience=30)
# Fold 4: Best Epoch = 74, Val_R² = 0.9631
# Fold 5: Early stopping at epoch 176 (patience=30)
# Fold 5: Best Epoch = 146, Val_R² = 0.9814
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 135 (patience=30)
# Fold 1: Best Epoch = 105, Val_R² = 0.9700
# Fold 2: Early stopping at epoch 117 (patience=30)
# Fold 2: Best Epoch = 87, Val_R² = 0.9749
# Fold 3: Early stopping at epoch 202 (patience=30)
# Fold 3: Best Epoch = 172, Val_R² = 0.9650
# Fold 4: Early stopping at epoch 91 (patience=30)
# Fold 4: Best Epoch = 61, Val_R² = 0.9623
# Fold 5: Early stopping at epoch 160 (patience=30)
# Fold 5: Best Epoch = 130, Val_R² = 0.9815
# Combination lr=0.005, patience=30, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9708, Avg Best Epoch = 111.00
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 112 (patience=30)
# Fold 1: Best Epoch = 82, Val_R² = 0.9691
# Fold 2: Early stopping at epoch 131 (patience=30)
# Fold 2: Best Epoch = 101, Val_R² = 0.9758
# Fold 3: Early stopping at epoch 206 (patience=30)
# Fold 3: Best Epoch = 176, Val_R² = 0.9634
# Fold 4: Early stopping at epoch 107 (patience=30)
# Fold 4: Best Epoch = 77, Val_R² = 0.9645
# Fold 5: Early stopping at epoch 190 (patience=30)
# Fold 5: Best Epoch = 160, Val_R² = 0.9807
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 71 (patience=30)
# Fold 1: Best Epoch = 41, Val_R² = 0.9670
# Fold 2: Early stopping at epoch 121 (patience=30)
# Fold 2: Best Epoch = 91, Val_R² = 0.9761
# Fold 3: Early stopping at epoch 244 (patience=30)
# Fold 3: Best Epoch = 214, Val_R² = 0.9648
# Fold 4: Early stopping at epoch 95 (patience=30)
# Fold 4: Best Epoch = 65, Val_R² = 0.9636
# Fold 5: Early stopping at epoch 168 (patience=30)
# Fold 5: Best Epoch = 138, Val_R² = 0.9815
#
# Testing combination: learning_rate=0.005, patience=30, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 126 (patience=30)
# Fold 1: Best Epoch = 96, Val_R² = 0.9700
# Fold 2: Early stopping at epoch 113 (patience=30)
# Fold 2: Best Epoch = 83, Val_R² = 0.9751
# Fold 3: Early stopping at epoch 215 (patience=30)
# Fold 3: Best Epoch = 185, Val_R² = 0.9658
# Fold 4: Early stopping at epoch 99 (patience=30)
# Fold 4: Best Epoch = 69, Val_R² = 0.9643
# Fold 5: Early stopping at epoch 162 (patience=30)
# Fold 5: Best Epoch = 132, Val_R² = 0.9813
# Combination lr=0.005, patience=30, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9713, Avg Best Epoch = 113.00
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 39 (patience=10)
# Fold 1: Best Epoch = 29, Val_R² = 0.9480
# Fold 2: Early stopping at epoch 45 (patience=10)
# Fold 2: Best Epoch = 35, Val_R² = 0.9611
# Fold 3: Early stopping at epoch 47 (patience=10)
# Fold 3: Best Epoch = 37, Val_R² = 0.9523
# Fold 4: Early stopping at epoch 44 (patience=10)
# Fold 4: Best Epoch = 34, Val_R² = 0.9466
# Fold 5: Early stopping at epoch 51 (patience=10)
# Fold 5: Best Epoch = 41, Val_R² = 0.9765
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 44 (patience=10)
# Fold 1: Best Epoch = 34, Val_R² = 0.9571
# Fold 2: Early stopping at epoch 40 (patience=10)
# Fold 2: Best Epoch = 30, Val_R² = 0.9712
# Fold 3: Early stopping at epoch 82 (patience=10)
# Fold 3: Best Epoch = 72, Val_R² = 0.9643
# Fold 4: Early stopping at epoch 40 (patience=10)
# Fold 4: Best Epoch = 30, Val_R² = 0.9546
# Fold 5: Early stopping at epoch 45 (patience=10)
# Fold 5: Best Epoch = 35, Val_R² = 0.9716
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 61 (patience=10)
# Fold 1: Best Epoch = 51, Val_R² = 0.9662
# Fold 2: Early stopping at epoch 31 (patience=10)
# Fold 2: Best Epoch = 21, Val_R² = 0.9652
# Fold 3: Early stopping at epoch 138 (patience=10)
# Fold 3: Best Epoch = 128, Val_R² = 0.9666
# Fold 4: Early stopping at epoch 34 (patience=10)
# Fold 4: Best Epoch = 24, Val_R² = 0.9511
# Fold 5: Early stopping at epoch 33 (patience=10)
# Fold 5: Best Epoch = 23, Val_R² = 0.9782
# Combination lr=0.01, patience=10, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9654, Avg Best Epoch = 49.40
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 49 (patience=10)
# Fold 1: Best Epoch = 39, Val_R² = 0.9576
# Fold 2: Early stopping at epoch 46 (patience=10)
# Fold 2: Best Epoch = 36, Val_R² = 0.9718
# Fold 3: Early stopping at epoch 44 (patience=10)
# Fold 3: Best Epoch = 34, Val_R² = 0.9474
# Fold 4: Early stopping at epoch 40 (patience=10)
# Fold 4: Best Epoch = 30, Val_R² = 0.9465
# Fold 5: Early stopping at epoch 42 (patience=10)
# Fold 5: Best Epoch = 32, Val_R² = 0.9694
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 29 (patience=10)
# Fold 1: Best Epoch = 19, Val_R² = 0.9615
# Fold 2: Early stopping at epoch 40 (patience=10)
# Fold 2: Best Epoch = 30, Val_R² = 0.9670
# Fold 3: Early stopping at epoch 11 (patience=10)
# Fold 3: Best Epoch = 1, Val_R² = 0.0171
# Fold 4: Early stopping at epoch 76 (patience=10)
# Fold 4: Best Epoch = 66, Val_R² = 0.9644
# Fold 5: Early stopping at epoch 45 (patience=10)
# Fold 5: Best Epoch = 35, Val_R² = 0.9771
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 46 (patience=10)
# Fold 1: Best Epoch = 36, Val_R² = 0.9594
# Fold 2: Early stopping at epoch 49 (patience=10)
# Fold 2: Best Epoch = 39, Val_R² = 0.9699
# Fold 3: Early stopping at epoch 72 (patience=10)
# Fold 3: Best Epoch = 62, Val_R² = 0.9653
# Fold 4: Early stopping at epoch 73 (patience=10)
# Fold 4: Best Epoch = 63, Val_R² = 0.9668
# Fold 5: Early stopping at epoch 42 (patience=10)
# Fold 5: Best Epoch = 32, Val_R² = 0.9682
# Combination lr=0.01, patience=10, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9659, Avg Best Epoch = 46.40
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 70 (patience=10)
# Fold 1: Best Epoch = 60, Val_R² = 0.9684
# Fold 2: Early stopping at epoch 48 (patience=10)
# Fold 2: Best Epoch = 38, Val_R² = 0.9693
# Fold 3: Early stopping at epoch 71 (patience=10)
# Fold 3: Best Epoch = 61, Val_R² = 0.9610
# Fold 4: Early stopping at epoch 53 (patience=10)
# Fold 4: Best Epoch = 43, Val_R² = 0.9581
# Fold 5: Early stopping at epoch 44 (patience=10)
# Fold 5: Best Epoch = 34, Val_R² = 0.9744
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 43 (patience=10)
# Fold 1: Best Epoch = 33, Val_R² = 0.9655
# Fold 2: Early stopping at epoch 44 (patience=10)
# Fold 2: Best Epoch = 34, Val_R² = 0.9698
# Fold 3: Early stopping at epoch 44 (patience=10)
# Fold 3: Best Epoch = 34, Val_R² = 0.9540
# Fold 4: Early stopping at epoch 44 (patience=10)
# Fold 4: Best Epoch = 34, Val_R² = 0.9535
# Fold 5: Early stopping at epoch 52 (patience=10)
# Fold 5: Best Epoch = 42, Val_R² = 0.9765
#
# Testing combination: learning_rate=0.01, patience=10, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 33 (patience=10)
# Fold 1: Best Epoch = 23, Val_R² = 0.9582
# Fold 2: Early stopping at epoch 38 (patience=10)
# Fold 2: Best Epoch = 28, Val_R² = 0.9658
# Fold 3: Early stopping at epoch 34 (patience=10)
# Fold 3: Best Epoch = 24, Val_R² = 0.9440
# Fold 4: Early stopping at epoch 63 (patience=10)
# Fold 4: Best Epoch = 53, Val_R² = 0.9666
# Fold 5: Early stopping at epoch 55 (patience=10)
# Fold 5: Best Epoch = 45, Val_R² = 0.9787
# Combination lr=0.01, patience=10, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9627, Avg Best Epoch = 34.60
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 67 (patience=20)
# Fold 1: Best Epoch = 47, Val_R² = 0.9669
# Fold 2: Early stopping at epoch 100 (patience=20)
# Fold 2: Best Epoch = 80, Val_R² = 0.9765
# Fold 3: Early stopping at epoch 96 (patience=20)
# Fold 3: Best Epoch = 76, Val_R² = 0.9627
# Fold 4: Early stopping at epoch 87 (patience=20)
# Fold 4: Best Epoch = 67, Val_R² = 0.9652
# Fold 5: Early stopping at epoch 87 (patience=20)
# Fold 5: Best Epoch = 67, Val_R² = 0.9809
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 71 (patience=20)
# Fold 1: Best Epoch = 51, Val_R² = 0.9670
# Fold 2: Early stopping at epoch 50 (patience=20)
# Fold 2: Best Epoch = 30, Val_R² = 0.9689
# Fold 3: Early stopping at epoch 166 (patience=20)
# Fold 3: Best Epoch = 146, Val_R² = 0.9651
# Fold 4: Early stopping at epoch 80 (patience=20)
# Fold 4: Best Epoch = 60, Val_R² = 0.9662
# Fold 5: Early stopping at epoch 99 (patience=20)
# Fold 5: Best Epoch = 79, Val_R² = 0.9812
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 73 (patience=20)
# Fold 1: Best Epoch = 53, Val_R² = 0.9669
# Fold 2: Early stopping at epoch 62 (patience=20)
# Fold 2: Best Epoch = 42, Val_R² = 0.9719
# Fold 3: Early stopping at epoch 76 (patience=20)
# Fold 3: Best Epoch = 56, Val_R² = 0.9658
# Fold 4: Early stopping at epoch 82 (patience=20)
# Fold 4: Best Epoch = 62, Val_R² = 0.9678
# Fold 5: Early stopping at epoch 85 (patience=20)
# Fold 5: Best Epoch = 65, Val_R² = 0.9810
# Combination lr=0.01, patience=20, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9707, Avg Best Epoch = 55.60
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 122 (patience=20)
# Fold 1: Best Epoch = 102, Val_R² = 0.9690
# Fold 2: Early stopping at epoch 94 (patience=20)
# Fold 2: Best Epoch = 74, Val_R² = 0.9770
# Fold 3: Early stopping at epoch 62 (patience=20)
# Fold 3: Best Epoch = 42, Val_R² = 0.9561
# Fold 4: Early stopping at epoch 49 (patience=20)
# Fold 4: Best Epoch = 29, Val_R² = 0.9519
# Fold 5: Early stopping at epoch 87 (patience=20)
# Fold 5: Best Epoch = 67, Val_R² = 0.9787
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 142 (patience=20)
# Fold 1: Best Epoch = 122, Val_R² = 0.9694
# Fold 2: Early stopping at epoch 95 (patience=20)
# Fold 2: Best Epoch = 75, Val_R² = 0.9760
# Fold 3: Early stopping at epoch 95 (patience=20)
# Fold 3: Best Epoch = 75, Val_R² = 0.9651
# Fold 4: Early stopping at epoch 86 (patience=20)
# Fold 4: Best Epoch = 66, Val_R² = 0.9664
# Fold 5: Early stopping at epoch 77 (patience=20)
# Fold 5: Best Epoch = 57, Val_R² = 0.9799
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 142 (patience=20)
# Fold 1: Best Epoch = 122, Val_R² = 0.9692
# Fold 2: Early stopping at epoch 43 (patience=20)
# Fold 2: Best Epoch = 23, Val_R² = 0.9701
# Fold 3: Early stopping at epoch 118 (patience=20)
# Fold 3: Best Epoch = 98, Val_R² = 0.9661
# Fold 4: Early stopping at epoch 78 (patience=20)
# Fold 4: Best Epoch = 58, Val_R² = 0.9674
# Fold 5: Early stopping at epoch 68 (patience=20)
# Fold 5: Best Epoch = 48, Val_R² = 0.9817
# Combination lr=0.01, patience=20, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9709, Avg Best Epoch = 69.80
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 70 (patience=20)
# Fold 1: Best Epoch = 50, Val_R² = 0.9655
# Fold 2: Early stopping at epoch 102 (patience=20)
# Fold 2: Best Epoch = 82, Val_R² = 0.9758
# Fold 3: Early stopping at epoch 93 (patience=20)
# Fold 3: Best Epoch = 73, Val_R² = 0.9618
# Fold 4: Early stopping at epoch 101 (patience=20)
# Fold 4: Best Epoch = 81, Val_R² = 0.9646
# Fold 5: Early stopping at epoch 119 (patience=20)
# Fold 5: Best Epoch = 99, Val_R² = 0.9804
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 117 (patience=20)
# Fold 1: Best Epoch = 97, Val_R² = 0.9699
# Fold 2: Early stopping at epoch 92 (patience=20)
# Fold 2: Best Epoch = 72, Val_R² = 0.9752
# Fold 3: Early stopping at epoch 158 (patience=20)
# Fold 3: Best Epoch = 138, Val_R² = 0.9646
# Fold 4: Early stopping at epoch 80 (patience=20)
# Fold 4: Best Epoch = 60, Val_R² = 0.9658
# Fold 5: Early stopping at epoch 78 (patience=20)
# Fold 5: Best Epoch = 58, Val_R² = 0.9800
#
# Testing combination: learning_rate=0.01, patience=20, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 130 (patience=20)
# Fold 1: Best Epoch = 110, Val_R² = 0.9697
# Fold 2: Early stopping at epoch 77 (patience=20)
# Fold 2: Best Epoch = 57, Val_R² = 0.9748
# Fold 3: Early stopping at epoch 123 (patience=20)
# Fold 3: Best Epoch = 103, Val_R² = 0.9667
# Fold 4: Early stopping at epoch 71 (patience=20)
# Fold 4: Best Epoch = 51, Val_R² = 0.9657
# Fold 5: Early stopping at epoch 96 (patience=20)
# Fold 5: Best Epoch = 76, Val_R² = 0.9808
# Combination lr=0.01, patience=20, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9716, Avg Best Epoch = 79.40
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=32, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 110 (patience=30)
# Fold 1: Best Epoch = 80, Val_R² = 0.9695
# Fold 2: Early stopping at epoch 118 (patience=30)
# Fold 2: Best Epoch = 88, Val_R² = 0.9747
# Fold 3: Early stopping at epoch 105 (patience=30)
# Fold 3: Best Epoch = 75, Val_R² = 0.9642
# Fold 4: Early stopping at epoch 115 (patience=30)
# Fold 4: Best Epoch = 85, Val_R² = 0.9656
# Fold 5: Early stopping at epoch 94 (patience=30)
# Fold 5: Best Epoch = 64, Val_R² = 0.9812
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=32, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 118 (patience=30)
# Fold 1: Best Epoch = 88, Val_R² = 0.9705
# Fold 2: Early stopping at epoch 105 (patience=30)
# Fold 2: Best Epoch = 75, Val_R² = 0.9753
# Fold 3: Early stopping at epoch 104 (patience=30)
# Fold 3: Best Epoch = 74, Val_R² = 0.9654
# Fold 4: Early stopping at epoch 93 (patience=30)
# Fold 4: Best Epoch = 63, Val_R² = 0.9666
# Fold 5: Early stopping at epoch 82 (patience=30)
# Fold 5: Best Epoch = 52, Val_R² = 0.9813
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=32, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 130 (patience=30)
# Fold 1: Best Epoch = 100, Val_R² = 0.9698
# Fold 2: Early stopping at epoch 85 (patience=30)
# Fold 2: Best Epoch = 55, Val_R² = 0.9747
# Fold 3: Early stopping at epoch 131 (patience=30)
# Fold 3: Best Epoch = 101, Val_R² = 0.9664
# Fold 4: Early stopping at epoch 94 (patience=30)
# Fold 4: Best Epoch = 64, Val_R² = 0.9656
# Fold 5: Early stopping at epoch 75 (patience=30)
# Fold 5: Best Epoch = 45, Val_R² = 0.9810
# Combination lr=0.01, patience=30, hidden_dim=32, lstm_hidden_dim=128: Avg Val_R² = 0.9715, Avg Best Epoch = 73.00
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=64, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 149 (patience=30)
# Fold 1: Best Epoch = 119, Val_R² = 0.9687
# Fold 2: Early stopping at epoch 117 (patience=30)
# Fold 2: Best Epoch = 87, Val_R² = 0.9750
# Fold 3: Early stopping at epoch 208 (patience=30)
# Fold 3: Best Epoch = 178, Val_R² = 0.9645
# Fold 4: Early stopping at epoch 94 (patience=30)
# Fold 4: Best Epoch = 64, Val_R² = 0.9662
# Fold 5: Early stopping at epoch 173 (patience=30)
# Fold 5: Best Epoch = 143, Val_R² = 0.9801
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=64, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 150 (patience=30)
# Fold 1: Best Epoch = 120, Val_R² = 0.9698
# Fold 2: Early stopping at epoch 116 (patience=30)
# Fold 2: Best Epoch = 86, Val_R² = 0.9755
# Fold 3: Early stopping at epoch 172 (patience=30)
# Fold 3: Best Epoch = 142, Val_R² = 0.9653
# Fold 4: Early stopping at epoch 97 (patience=30)
# Fold 4: Best Epoch = 67, Val_R² = 0.9651
# Fold 5: Early stopping at epoch 122 (patience=30)
# Fold 5: Best Epoch = 92, Val_R² = 0.9800
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=64, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 94 (patience=30)
# Fold 1: Best Epoch = 64, Val_R² = 0.9695
# Fold 2: Early stopping at epoch 96 (patience=30)
# Fold 2: Best Epoch = 66, Val_R² = 0.9754
# Fold 3: Early stopping at epoch 131 (patience=30)
# Fold 3: Best Epoch = 101, Val_R² = 0.9661
# Fold 4: Early stopping at epoch 90 (patience=30)
# Fold 4: Best Epoch = 60, Val_R² = 0.9686
# Fold 5: Early stopping at epoch 106 (patience=30)
# Fold 5: Best Epoch = 76, Val_R² = 0.9812
# Combination lr=0.01, patience=30, hidden_dim=64, lstm_hidden_dim=128: Avg Val_R² = 0.9721, Avg Best Epoch = 73.40
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=128, lstm_hidden_dim=32
# Fold 1: Early stopping at epoch 186 (patience=30)
# Fold 1: Best Epoch = 156, Val_R² = 0.9673
# Fold 2: Early stopping at epoch 104 (patience=30)
# Fold 2: Best Epoch = 74, Val_R² = 0.9768
# Fold 3: Early stopping at epoch 204 (patience=30)
# Fold 3: Best Epoch = 174, Val_R² = 0.9639
# Fold 4: Early stopping at epoch 99 (patience=30)
# Fold 4: Best Epoch = 69, Val_R² = 0.9643
# Fold 5: Early stopping at epoch 174 (patience=30)
# Fold 5: Best Epoch = 144, Val_R² = 0.9806
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=128, lstm_hidden_dim=64
# Fold 1: Early stopping at epoch 59 (patience=30)
# Fold 1: Best Epoch = 29, Val_R² = 0.9675
# Fold 2: Early stopping at epoch 110 (patience=30)
# Fold 2: Best Epoch = 80, Val_R² = 0.9753
# Fold 3: Early stopping at epoch 158 (patience=30)
# Fold 3: Best Epoch = 128, Val_R² = 0.9645
# Fold 4: Early stopping at epoch 96 (patience=30)
# Fold 4: Best Epoch = 66, Val_R² = 0.9663
# Fold 5: Early stopping at epoch 120 (patience=30)
# Fold 5: Best Epoch = 90, Val_R² = 0.9807
#
# Testing combination: learning_rate=0.01, patience=30, hidden_dim=128, lstm_hidden_dim=128
# Fold 1: Early stopping at epoch 134 (patience=30)
# Fold 1: Best Epoch = 104, Val_R² = 0.9693
# Fold 2: Early stopping at epoch 91 (patience=30)
# Fold 2: Best Epoch = 61, Val_R² = 0.9751
# Fold 3: Early stopping at epoch 114 (patience=30)
# Fold 3: Best Epoch = 84, Val_R² = 0.9647
# Fold 4: Early stopping at epoch 89 (patience=30)
# Fold 4: Best Epoch = 59, Val_R² = 0.9666
# Fold 5: Early stopping at epoch 109 (patience=30)
# Fold 5: Best Epoch = 79, Val_R² = 0.9806
# Combination lr=0.01, patience=30, hidden_dim=128, lstm_hidden_dim=128: Avg Val_R² = 0.9713, Avg Best Epoch = 77.40
#
# ====== Grid Search Completed ======
# Best hyperparameters from grid search:
# {'learning_rate': 0.01, 'patience': 30, 'hidden_dim': 64, 'lstm_hidden_dim': 128, 'avg_val_r2': 0.972149716724067, 'avg_best_epoch': 73.4}
# Final training epochs set to: 73

# %%
import pandas as pd
import numpy as np
import torch
import time
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 种子固定
np.random.seed(42)
torch.manual_seed(42)  # 设置 CPU 随机种子
torch.cuda.manual_seed(42)  # 设置 GPU 随机种子
torch.cuda.manual_seed_all(42)  # 如果使用多 GPU，设置所有 GPU 的随机种子
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# -------------------------
# 7. 使用最佳超参数以及数据训练最终模型，并对 2020-2022 预测
# -------------------------
# 对所有训练数据重新标准化
scaler_x_final = MinMaxScaler()
X_train_all_scaled = scaler_x_final.fit_transform(X_train_all)
scaler_y_final = MinMaxScaler()
y_train_all_scaled = scaler_y_final.fit_transform(y_train_all.values.reshape(-1, 1)).ravel()
train_data_final = build_graph(X_train_all_scaled).to(device)
y_train_all_scaled_t = torch.tensor(y_train_all_scaled, dtype=torch.float).to(device)

# Prepare LSTM input (time series features)
lstm_input_train = torch.tensor(X_train_all_scaled.reshape(-1, 1, X_train_all_scaled.shape[1]), dtype=torch.float).to(device)

results = []

print("\n====== Begin Final Training with Best Hyperparameters ======")
for i in range(10):
    print(f"\nFinal Training run {i+1}/10")
    start_time = time.time()
    
    # 使用修改后的 LSTM + GraphSAGE 模型
    model_final = LSTMGraphSAGEModel(num_node_features=X_train_all_scaled.shape[1],
                                     hidden_dim=best_hidden_dim,
                                     lstm_hidden_dim=best_lstm_hidden_dim,
                                     out_dim=1).to(device)
    optimizer_final = torch.optim.Adam(model_final.parameters(), lr=best_learning_rate)
    criterion_final = torch.nn.MSELoss()
    
    for epoch in range(final_num_epochs):
        model_final.train()
        optimizer_final.zero_grad()
        out_final = model_final(train_data_final, lstm_input=lstm_input_train).squeeze()  # 使用 LSTM 输入
        loss_final = criterion_final(out_final, y_train_all_scaled_t)
        loss_final.backward()
        # Apply gradient clipping (Flooding)
        # torch.nn.utils.clip_grad_norm_(model_final.parameters(), max_norm=1.0)  # 限制梯度最大范数为1.0
        
        optimizer_final.step()
        
        if (epoch+1) % 50 == 0:
            print(f"[Final Train] Epoch {epoch+1}/{final_num_epochs}, Loss: {loss_final.item():.4f}")
    
    model_filename = f'final_model_run_{i+1}.pth'
    torch.save(model_final.state_dict(), model_filename)
    
    def predict_and_evaluate(model, X_test, y_test):
        X_test_scaled = scaler_x_final.transform(X_test)
        data_test = build_graph(X_test_scaled).to(device)
        lstm_input_test = torch.tensor(X_test_scaled.reshape(-1, 1, X_test_scaled.shape[1]), dtype=torch.float).to(device)  # LSTM 输入
        y_test_t = torch.tensor(y_test.values, dtype=torch.float).to(device)
        
        model.eval()
        with torch.no_grad():
            preds_test = model(data_test, lstm_input=lstm_input_test).squeeze().cpu().numpy()
        preds_test_unscaled = scaler_y_final.inverse_transform(preds_test.reshape(-1, 1)).ravel()
        
        rmse = np.sqrt(mean_squared_error(y_test_t.cpu().numpy(), preds_test_unscaled))
        mae = mean_absolute_error(y_test_t.cpu().numpy(), preds_test_unscaled)
        r2 = r2_score(y_test_t.cpu().numpy(), preds_test_unscaled)
        nmae = mae / np.mean(y_test_t.cpu().numpy()) if np.mean(y_test_t.cpu().numpy()) != 0 else np.nan
        nrmse = rmse / np.mean(y_test_t.cpu().numpy()) if np.mean(y_test_t.cpu().numpy()) != 0 else np.nan
        return rmse, mae, r2, nmae, nrmse
    
    # 预测并评估 2020, 2021, 2022
    rmse_2020, mae_2020, r2_2020, nmae_2020, nrmse_2020 = predict_and_evaluate(model_final, X_test_2020, y_test_2020)
    rmse_2021, mae_2021, r2_2021, nmae_2021, nrmse_2021 = predict_and_evaluate(model_final, X_test_2021, y_test_2021)
    rmse_2022, mae_2022, r2_2022, nmae_2022, nrmse_2022 = predict_and_evaluate(model_final, X_test_2022, y_test_2022)
    
    end_time = time.time()
    training_time = end_time - start_time
    
    print(f"Run {i+1}: Training Time = {training_time:.2f} s")
    print(f"2020 - RMSE: {rmse_2020:.4f}, MAE: {mae_2020:.4f}, R²: {r2_2020:.4f}, NMAE: {nmae_2020:.4f}, NRMSE: {nrmse_2020:.4f}")
    print(f"2021 - RMSE: {rmse_2021:.4f}, MAE: {mae_2021:.4f}, R²: {r2_2021:.4f}, NMAE: {nmae_2021:.4f}, NRMSE: {nrmse_2021:.4f}")
    print(f"2022 - RMSE: {rmse_2022:.4f}, MAE: {mae_2022:.4f}, R²: {r2_2022:.4f}, NMAE: {nmae_2022:.4f}, NRMSE: {nrmse_2022:.4f}")
    
    results.append({
        'Run': i+1,
        'Training_Time (s)': training_time,
        'RMSE_2020': rmse_2020, 'MAE_2020': mae_2020, 'R²_2020': r2_2020, 'NMAE_2020': nmae_2020, 'NRMSE_2020': nrmse_2020,
        'RMSE_2021': rmse_2021, 'MAE_2021': mae_2021, 'R²_2021': r2_2021, 'NMAE_2021': nmae_2021, 'NRMSE_2021': nrmse_2021,
        'RMSE_2022': rmse_2022, 'MAE_2022': mae_2022, 'R²_2022': r2_2022, 'NMAE_2022': nmae_2022, 'NRMSE_2022': nrmse_2022
    })

# 保存结果
results_df = pd.DataFrame(results)
results_df.to_csv('model_training_results_with_time.csv', index=False)
print("\nResults saved to 'model_training_results_with_time.csv'.")
# Out:
# ====== Begin Final Training with Best Hyperparameters ======
#
# Final Training run 1/10
# [Final Train] Epoch 50/73, Loss: 0.0014
# Run 1: Training Time = 0.29 s
# 2020 - RMSE: 2558.6787, MAE: 2196.3499, R²: 0.9710, NMAE: 0.0610, NRMSE: 0.0711
# 2021 - RMSE: 3024.0015, MAE: 2603.0918, R²: 0.9622, NMAE: 0.0709, NRMSE: 0.0823
# 2022 - RMSE: 2624.2537, MAE: 2212.5034, R²: 0.9689, NMAE: 0.0602, NRMSE: 0.0714
#
# Final Training run 2/10
# [Final Train] Epoch 50/73, Loss: 0.0020
# Run 2: Training Time = 0.28 s
# 2020 - RMSE: 2731.5483, MAE: 2392.8748, R²: 0.9669, NMAE: 0.0665, NRMSE: 0.0759
# 2021 - RMSE: 3132.6265, MAE: 2712.1819, R²: 0.9594, NMAE: 0.0738, NRMSE: 0.0853
# 2022 - RMSE: 2643.1125, MAE: 2208.8911, R²: 0.9685, NMAE: 0.0601, NRMSE: 0.0719
#
# Final Training run 3/10
# [Final Train] Epoch 50/73, Loss: 0.0024
# Run 3: Training Time = 0.28 s
# 2020 - RMSE: 2439.3252, MAE: 2144.3914, R²: 0.9736, NMAE: 0.0596, NRMSE: 0.0677
# 2021 - RMSE: 2858.5986, MAE: 2457.9446, R²: 0.9662, NMAE: 0.0669, NRMSE: 0.0778
# 2022 - RMSE: 2586.2866, MAE: 2210.4355, R²: 0.9698, NMAE: 0.0601, NRMSE: 0.0703
#
# Final Training run 4/10
# [Final Train] Epoch 50/73, Loss: 0.0023
# Run 4: Training Time = 0.28 s
# 2020 - RMSE: 2639.0635, MAE: 2330.2361, R²: 0.9691, NMAE: 0.0647, NRMSE: 0.0733
# 2021 - RMSE: 3032.4197, MAE: 2627.4451, R²: 0.9619, NMAE: 0.0715, NRMSE: 0.0825
# 2022 - RMSE: 2532.5747, MAE: 2158.0610, R²: 0.9710, NMAE: 0.0587, NRMSE: 0.0689
#
# Final Training run 5/10
# [Final Train] Epoch 50/73, Loss: 0.0015
# Run 5: Training Time = 0.28 s
# 2020 - RMSE: 2508.2888, MAE: 2182.0696, R²: 0.9721, NMAE: 0.0606, NRMSE: 0.0697
# 2021 - RMSE: 2963.7024, MAE: 2518.0198, R²: 0.9636, NMAE: 0.0685, NRMSE: 0.0807
# 2022 - RMSE: 2685.1438, MAE: 2314.3735, R²: 0.9674, NMAE: 0.0629, NRMSE: 0.0730
#
# Final Training run 6/10
# [Final Train] Epoch 50/73, Loss: 0.0015
# Run 6: Training Time = 0.28 s
# 2020 - RMSE: 2497.7561, MAE: 2162.0081, R²: 0.9724, NMAE: 0.0600, NRMSE: 0.0694
# 2021 - RMSE: 3035.4998, MAE: 2551.1401, R²: 0.9619, NMAE: 0.0694, NRMSE: 0.0826
# 2022 - RMSE: 2638.9924, MAE: 2233.2236, R²: 0.9685, NMAE: 0.0607, NRMSE: 0.0718
#
# Final Training run 7/10
# [Final Train] Epoch 50/73, Loss: 0.0016
# Run 7: Training Time = 0.28 s
# 2020 - RMSE: 2878.6045, MAE: 2486.6531, R²: 0.9633, NMAE: 0.0691, NRMSE: 0.0799
# 2021 - RMSE: 3279.0103, MAE: 2814.6614, R²: 0.9555, NMAE: 0.0766, NRMSE: 0.0893
# 2022 - RMSE: 2701.6472, MAE: 2198.6926, R²: 0.9670, NMAE: 0.0598, NRMSE: 0.0735
#
# Final Training run 8/10
# [Final Train] Epoch 50/73, Loss: 0.0015
# Run 8: Training Time = 0.28 s
# 2020 - RMSE: 2527.5920, MAE: 2207.7400, R²: 0.9717, NMAE: 0.0613, NRMSE: 0.0702
# 2021 - RMSE: 2992.7637, MAE: 2548.1145, R²: 0.9629, NMAE: 0.0694, NRMSE: 0.0815
# 2022 - RMSE: 2597.6580, MAE: 2209.4744, R²: 0.9695, NMAE: 0.0601, NRMSE: 0.0706
#
# Final Training run 9/10
# [Final Train] Epoch 50/73, Loss: 0.0018
# Run 9: Training Time = 0.28 s
# 2020 - RMSE: 2535.2771, MAE: 2235.5947, R²: 0.9715, NMAE: 0.0621, NRMSE: 0.0704
# 2021 - RMSE: 2884.4072, MAE: 2503.0227, R²: 0.9656, NMAE: 0.0681, NRMSE: 0.0785
# 2022 - RMSE: 2526.4299, MAE: 2147.9939, R²: 0.9712, NMAE: 0.0584, NRMSE: 0.0687
#
# Final Training run 10/10
# [Final Train] Epoch 50/73, Loss: 0.0022
# Run 10: Training Time = 0.28 s
# 2020 - RMSE: 2470.2000, MAE: 2111.7983, R²: 0.9730, NMAE: 0.0587, NRMSE: 0.0686
# 2021 - RMSE: 2894.6077, MAE: 2437.5283, R²: 0.9653, NMAE: 0.0663, NRMSE: 0.0788
# 2022 - RMSE: 2679.6709, MAE: 2281.1885, R²: 0.9676, NMAE: 0.0620, NRMSE: 0.0729
#
# Results saved to 'model_training_results_with_time.csv'.
