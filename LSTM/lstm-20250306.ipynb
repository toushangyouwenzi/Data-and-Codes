# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/all-province/all_province_data.xlsx

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold
import time
# 种子固定
np.random.seed(42)
torch.manual_seed(42)  # 设置 CPU 随机种子
torch.cuda.manual_seed(42)  # 设置 GPU 随机种子
torch.cuda.manual_seed_all(42)  # 如果使用多 GPU，设置所有 GPU 的随机种子
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# ===============================
# 1. 数据预处理
# ===============================
file_path = '/kaggle/input/all-province/all_province_data.xlsx'
data = pd.read_excel(file_path)
data['Year'] = data['时间'].str.extract('(\d+)').astype(int)
data = pd.get_dummies(data, columns=['Province'])

# 选择特征
features = [
    'Year', 'Ammonia Nitrogen Emissions', 'Average Temperature',
    'Average Years of Education per Capita', 'Chemical Oxygen Demand Emissions',
    'Electricity Consumption', 'Geographic-Mean PM2',
    'Government Expenditure on Environmental Protection',
    'NOx Emissions', 'Number of Healthcare Institutions',
    'Number of Healthcare Personnel', 'Oil Emissions',
    'Per Capita Disposable Income', 'Resident Population',
    'SO2 Emissions', 'Total Nitrogen Emissions',
    'Total Phosphorus Emissions'
] + list(data.columns[data.columns.str.startswith('Province_')])

X = data[features]
y = data['Total CO2 emissions']
X = X.fillna(X.mean())

# 划分训练集和测试集
X_test_2020 = X[X['Year'] == 2020]
X_test_2021 = X[X['Year'] == 2021]
X_test_2022 = X[X['Year'] == 2022]
y_test_2020 = y[X['Year'] == 2020]
y_test_2021 = y[X['Year'] == 2021]
y_test_2022 = y[X['Year'] == 2022]
X_train_all = X[~X['Year'].isin([2020, 2021, 2022])]
y_train_all = y[~X['Year'].isin([2020, 2021, 2022])]

# 标准化数据
scaler_x = MinMaxScaler()
X_train_all_scaled = scaler_x.fit_transform(X_train_all)
X_test_2020_scaled = scaler_x.transform(X_test_2020)
X_test_2021_scaled = scaler_x.transform(X_test_2021)
X_test_2022_scaled = scaler_x.transform(X_test_2022)

scaler_y = MinMaxScaler()
y_train_all_scaled = scaler_y.fit_transform(y_train_all.values.reshape(-1, 1)).ravel()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# ===============================
# 2. 定义 LSTM 模型
# ===============================
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = x.unsqueeze(1)  # (batch_size, 1, num_features)
        out, _ = self.lstm(x)
        x = self.fc(out[:, -1, :])  # 取最后一个时间步的输出
        return x


# ===============================
# 3. 五折交叉验证 (超参数选择)
# ===============================
candidate_learning_rates = [0.001, 0.005, 0.01]
candidate_hidden_dims = [32, 64, 128]
candidate_patience_values = [10, 20, 30]

num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)
best_hyperparams = None
best_avg_r2 = float('-inf')

print("\n====== Begin LSTM Grid Search ======")
for lr in candidate_learning_rates:
    for hidden_dim in candidate_hidden_dims:
        for patience in candidate_patience_values:
            print(f"\nTesting Learning Rate: {lr}, Hidden Dim: {hidden_dim}, Patience: {patience}")
            fold_r2_scores = []
            fold_best_epochs = []

            for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_all_scaled), 1):
                print(f"  Fold {fold} - Training...")

                X_train_fold, X_val_fold = X_train_all_scaled[train_idx], X_train_all_scaled[val_idx]
                y_train_fold, y_val_fold = y_train_all_scaled[train_idx], y_train_all_scaled[val_idx]

                X_train_tensor = torch.tensor(X_train_fold, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train_fold, dtype=torch.float32).to(device)
                X_val_tensor = torch.tensor(X_val_fold, dtype=torch.float32).to(device)
                y_val_tensor = torch.tensor(y_val_fold, dtype=torch.float32).to(device)

                model = LSTMModel(X_train_all.shape[1], hidden_dim, 1).to(device)
                optimizer = optim.Adam(model.parameters(), lr=lr)
                criterion = nn.MSELoss()

                best_val_r2 = float('-inf')
                best_epoch = 0
                no_improve_counter = 0
                max_epochs = 1000
                
                for epoch in range(max_epochs):
                    model.train()
                    optimizer.zero_grad()
                    predictions = model(X_train_tensor).squeeze()
                    loss = criterion(predictions, y_train_tensor)
                    loss.backward()
                    optimizer.step()

                    model.eval()
                    with torch.no_grad():
                        preds_val = model(X_val_tensor).squeeze().cpu().numpy()
                    val_r2 = r2_score(y_val_tensor.cpu().numpy(), preds_val)

                    if val_r2 > best_val_r2:
                        best_val_r2 = val_r2
                        best_epoch = epoch + 1
                        no_improve_counter = 0
                    else:
                        no_improve_counter += 1
                    if no_improve_counter >= patience:
                        print(f"    Fold {fold}: Early stopping at epoch {epoch+1} (patience={patience})")
                        break

                fold_r2_scores.append(best_val_r2)
                fold_best_epochs.append(best_epoch)
                print(f"    Fold {fold}: Best Epoch = {best_epoch}, Val_R² = {best_val_r2:.4f}")

            avg_r2 = np.mean(fold_r2_scores)
            avg_best_epoch = np.mean(fold_best_epochs)

            print(f"Avg R² for this set of hyperparameters: {avg_r2:.4f}")

            if avg_r2 > best_avg_r2:
                best_avg_r2 = avg_r2
                best_hyperparams = (lr, hidden_dim, avg_best_epoch)

print("\n====== LSTM Grid Search Completed ======")
best_learning_rate, best_hidden_dim, final_num_epochs = best_hyperparams
print(f"Best Hyperparameters: Learning Rate = {best_learning_rate}, Hidden Dim = {best_hidden_dim}, Epochs = {int(final_num_epochs)}")

# ===============================
# 4. 计算 RMSE、MAE、R²、NMAE、NRMSE
# ===============================
def evaluate_model(model, X_test, y_test):
    X_test_scaled = scaler_x.transform(X_test)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
    y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).to(device)

    model.eval()
    with torch.no_grad():
        preds_test = model(X_test_tensor).squeeze().cpu().numpy()
    preds_test_unscaled = scaler_y.inverse_transform(preds_test.reshape(-1, 1)).ravel()

    rmse = np.sqrt(mean_squared_error(y_test, preds_test_unscaled))
    mae = mean_absolute_error(y_test, preds_test_unscaled)
    r2 = r2_score(y_test, preds_test_unscaled)
    nmae = mae / np.mean(y_test) if np.mean(y_test) != 0 else np.nan
    nrmse = rmse / np.mean(y_test) if np.mean(y_test) != 0 else np.nan

    return rmse, mae, r2, nmae, nrmse

# ===============================
# 5. 10 次训练，保存结果
# ===============================

results = []

for i in range(10):
    print(f"\n====== Training LSTM Run {i+1}/10 ======")
    start_time = time.time()
    
    # 初始化 LSTM 模型
    model = LSTMModel(X_train_all.shape[1], best_hidden_dim, 1).to(device)
    optimizer = optim.Adam(model.parameters(), lr=best_learning_rate)
    criterion = nn.MSELoss()

    # 训练模型
    for epoch in range(int(final_num_epochs)):
        model.train()
        optimizer.zero_grad()
        predictions = model(torch.tensor(X_train_all_scaled, dtype=torch.float32).to(device)).squeeze()
        loss = criterion(predictions, torch.tensor(y_train_all_scaled, dtype=torch.float32).to(device))
        loss.backward()
        optimizer.step()

    # 计算训练时间
    end_time = time.time()
    training_time = end_time - start_time

    # 保存模型
    model_filename = f'final_LSTM_model_run_{i+1}.pth'
    torch.save(model.state_dict(), model_filename)
    print(f"Model {i+1} saved as {model_filename}")

    # 评估模型在 2020、2021、2022 上的表现
    rmse_2020, mae_2020, r2_2020, nmae_2020, nrmse_2020 = evaluate_model(model, X_test_2020, y_test_2020)
    rmse_2021, mae_2021, r2_2021, nmae_2021, nrmse_2021 = evaluate_model(model, X_test_2021, y_test_2021)
    rmse_2022, mae_2022, r2_2022, nmae_2022, nrmse_2022 = evaluate_model(model, X_test_2022, y_test_2022)

    print(f"Run {i+1}: Training Time = {training_time:.2f} s")
    print(f"2020 - RMSE: {rmse_2020:.4f}, MAE: {mae_2020:.4f}, R²: {r2_2020:.4f}, NMAE: {nmae_2020:.4f}, NRMSE: {nrmse_2020:.4f}")
    print(f"2021 - RMSE: {rmse_2021:.4f}, MAE: {mae_2021:.4f}, R²: {r2_2021:.4f}, NMAE: {nmae_2021:.4f}, NRMSE: {nrmse_2021:.4f}")
    print(f"2022 - RMSE: {rmse_2022:.4f}, MAE: {mae_2022:.4f}, R²: {r2_2022:.4f}, NMAE: {nmae_2022:.4f}, NRMSE: {nrmse_2022:.4f}")

    # 记录结果
    results.append({
        'Run': i+1,
        'Training Time (s)': training_time,
        'RMSE_2020': rmse_2020, 'MAE_2020': mae_2020, 'R²_2020': r2_2020, 'NMAE_2020': nmae_2020, 'NRMSE_2020': nrmse_2020,
        'RMSE_2021': rmse_2021, 'MAE_2021': mae_2021, 'R²_2021': r2_2021, 'NMAE_2021': nmae_2021, 'NRMSE_2021': nrmse_2021,
        'RMSE_2022': rmse_2022, 'MAE_2022': mae_2022, 'R²_2022': r2_2022, 'NMAE_2022': nmae_2022, 'NRMSE_2022': nrmse_2022
    })

# 保存结果到 CSV
df_results = pd.DataFrame(results)
df_results.to_csv("LSTM_results.csv", index=False)
print("Results saved to LSTM_results.csv")
# Out:
# Using device: cuda
#
# ====== Begin LSTM Grid Search ======
#
# Testing Learning Rate: 0.001, Hidden Dim: 32, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 399 (patience=10)
#     Fold 1: Best Epoch = 389, Val_R² = 0.9696
#   Fold 2 - Training...
#     Fold 2: Best Epoch = 1000, Val_R² = 0.9734
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 238 (patience=10)
#     Fold 3: Best Epoch = 228, Val_R² = 0.9578
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 221 (patience=10)
#     Fold 4: Best Epoch = 211, Val_R² = 0.9555
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 868 (patience=10)
#     Fold 5: Best Epoch = 858, Val_R² = 0.9807
# Avg R² for this set of hyperparameters: 0.9674
#
# Testing Learning Rate: 0.001, Hidden Dim: 32, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 854 (patience=20)
#     Fold 1: Best Epoch = 834, Val_R² = 0.9688
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 575 (patience=20)
#     Fold 2: Best Epoch = 555, Val_R² = 0.9742
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 269 (patience=20)
#     Fold 3: Best Epoch = 249, Val_R² = 0.9569
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 855 (patience=20)
#     Fold 4: Best Epoch = 835, Val_R² = 0.9616
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 574 (patience=20)
#     Fold 5: Best Epoch = 554, Val_R² = 0.9804
# Avg R² for this set of hyperparameters: 0.9684
#
# Testing Learning Rate: 0.001, Hidden Dim: 32, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 761 (patience=30)
#     Fold 1: Best Epoch = 731, Val_R² = 0.9681
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 627 (patience=30)
#     Fold 2: Best Epoch = 597, Val_R² = 0.9727
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 745 (patience=30)
#     Fold 3: Best Epoch = 715, Val_R² = 0.9633
#   Fold 4 - Training...
#     Fold 4: Best Epoch = 1000, Val_R² = 0.9603
#   Fold 5 - Training...
#     Fold 5: Best Epoch = 1000, Val_R² = 0.9782
# Avg R² for this set of hyperparameters: 0.9685
#
# Testing Learning Rate: 0.001, Hidden Dim: 64, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 699 (patience=10)
#     Fold 1: Best Epoch = 689, Val_R² = 0.9694
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 351 (patience=10)
#     Fold 2: Best Epoch = 341, Val_R² = 0.9733
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 212 (patience=10)
#     Fold 3: Best Epoch = 202, Val_R² = 0.9558
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 139 (patience=10)
#     Fold 4: Best Epoch = 129, Val_R² = 0.9528
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 519 (patience=10)
#     Fold 5: Best Epoch = 509, Val_R² = 0.9807
# Avg R² for this set of hyperparameters: 0.9664
#
# Testing Learning Rate: 0.001, Hidden Dim: 64, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 809 (patience=20)
#     Fold 1: Best Epoch = 789, Val_R² = 0.9689
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 358 (patience=20)
#     Fold 2: Best Epoch = 338, Val_R² = 0.9732
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 234 (patience=20)
#     Fold 3: Best Epoch = 214, Val_R² = 0.9585
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 182 (patience=20)
#     Fold 4: Best Epoch = 162, Val_R² = 0.9551
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 650 (patience=20)
#     Fold 5: Best Epoch = 630, Val_R² = 0.9807
# Avg R² for this set of hyperparameters: 0.9673
#
# Testing Learning Rate: 0.001, Hidden Dim: 64, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 806 (patience=30)
#     Fold 1: Best Epoch = 776, Val_R² = 0.9690
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 439 (patience=30)
#     Fold 2: Best Epoch = 409, Val_R² = 0.9730
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 734 (patience=30)
#     Fold 3: Best Epoch = 704, Val_R² = 0.9652
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 173 (patience=30)
#     Fold 4: Best Epoch = 143, Val_R² = 0.9572
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 670 (patience=30)
#     Fold 5: Best Epoch = 640, Val_R² = 0.9803
# Avg R² for this set of hyperparameters: 0.9689
#
# Testing Learning Rate: 0.001, Hidden Dim: 128, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 197 (patience=10)
#     Fold 1: Best Epoch = 187, Val_R² = 0.9680
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 319 (patience=10)
#     Fold 2: Best Epoch = 309, Val_R² = 0.9736
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 127 (patience=10)
#     Fold 3: Best Epoch = 117, Val_R² = 0.9563
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 34 (patience=10)
#     Fold 4: Best Epoch = 24, Val_R² = 0.2996
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 476 (patience=10)
#     Fold 5: Best Epoch = 466, Val_R² = 0.9808
# Avg R² for this set of hyperparameters: 0.8356
#
# Testing Learning Rate: 0.001, Hidden Dim: 128, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 397 (patience=20)
#     Fold 1: Best Epoch = 377, Val_R² = 0.9694
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 424 (patience=20)
#     Fold 2: Best Epoch = 404, Val_R² = 0.9733
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 134 (patience=20)
#     Fold 3: Best Epoch = 114, Val_R² = 0.9591
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 149 (patience=20)
#     Fold 4: Best Epoch = 129, Val_R² = 0.9549
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 508 (patience=20)
#     Fold 5: Best Epoch = 488, Val_R² = 0.9805
# Avg R² for this set of hyperparameters: 0.9674
#
# Testing Learning Rate: 0.001, Hidden Dim: 128, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 440 (patience=30)
#     Fold 1: Best Epoch = 410, Val_R² = 0.9694
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 390 (patience=30)
#     Fold 2: Best Epoch = 360, Val_R² = 0.9729
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 160 (patience=30)
#     Fold 3: Best Epoch = 130, Val_R² = 0.9569
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 156 (patience=30)
#     Fold 4: Best Epoch = 126, Val_R² = 0.9540
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 621 (patience=30)
#     Fold 5: Best Epoch = 591, Val_R² = 0.9804
# Avg R² for this set of hyperparameters: 0.9667
#
# Testing Learning Rate: 0.005, Hidden Dim: 32, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 101 (patience=10)
#     Fold 1: Best Epoch = 91, Val_R² = 0.9697
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 279 (patience=10)
#     Fold 2: Best Epoch = 269, Val_R² = 0.9730
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 321 (patience=10)
#     Fold 3: Best Epoch = 311, Val_R² = 0.9652
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 115 (patience=10)
#     Fold 4: Best Epoch = 105, Val_R² = 0.9618
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 491 (patience=10)
#     Fold 5: Best Epoch = 481, Val_R² = 0.9787
# Avg R² for this set of hyperparameters: 0.9697
#
# Testing Learning Rate: 0.005, Hidden Dim: 32, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 99 (patience=20)
#     Fold 1: Best Epoch = 79, Val_R² = 0.9694
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 142 (patience=20)
#     Fold 2: Best Epoch = 122, Val_R² = 0.9745
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 277 (patience=20)
#     Fold 3: Best Epoch = 257, Val_R² = 0.9658
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 122 (patience=20)
#     Fold 4: Best Epoch = 102, Val_R² = 0.9607
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 251 (patience=20)
#     Fold 5: Best Epoch = 231, Val_R² = 0.9803
# Avg R² for this set of hyperparameters: 0.9701
#
# Testing Learning Rate: 0.005, Hidden Dim: 32, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 126 (patience=30)
#     Fold 1: Best Epoch = 96, Val_R² = 0.9688
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 140 (patience=30)
#     Fold 2: Best Epoch = 110, Val_R² = 0.9740
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 404 (patience=30)
#     Fold 3: Best Epoch = 374, Val_R² = 0.9656
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 107 (patience=30)
#     Fold 4: Best Epoch = 77, Val_R² = 0.9589
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 215 (patience=30)
#     Fold 5: Best Epoch = 185, Val_R² = 0.9803
# Avg R² for this set of hyperparameters: 0.9695
#
# Testing Learning Rate: 0.005, Hidden Dim: 64, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 103 (patience=10)
#     Fold 1: Best Epoch = 93, Val_R² = 0.9681
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 134 (patience=10)
#     Fold 2: Best Epoch = 124, Val_R² = 0.9739
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 58 (patience=10)
#     Fold 3: Best Epoch = 48, Val_R² = 0.9561
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 78 (patience=10)
#     Fold 4: Best Epoch = 68, Val_R² = 0.9590
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 87 (patience=10)
#     Fold 5: Best Epoch = 77, Val_R² = 0.9786
# Avg R² for this set of hyperparameters: 0.9671
#
# Testing Learning Rate: 0.005, Hidden Dim: 64, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 105 (patience=20)
#     Fold 1: Best Epoch = 85, Val_R² = 0.9687
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 189 (patience=20)
#     Fold 2: Best Epoch = 169, Val_R² = 0.9730
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 265 (patience=20)
#     Fold 3: Best Epoch = 245, Val_R² = 0.9663
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 93 (patience=20)
#     Fold 4: Best Epoch = 73, Val_R² = 0.9593
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 116 (patience=20)
#     Fold 5: Best Epoch = 96, Val_R² = 0.9812
# Avg R² for this set of hyperparameters: 0.9697
#
# Testing Learning Rate: 0.005, Hidden Dim: 64, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 190 (patience=30)
#     Fold 1: Best Epoch = 160, Val_R² = 0.9692
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 219 (patience=30)
#     Fold 2: Best Epoch = 189, Val_R² = 0.9742
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 306 (patience=30)
#     Fold 3: Best Epoch = 276, Val_R² = 0.9658
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 262 (patience=30)
#     Fold 4: Best Epoch = 232, Val_R² = 0.9642
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 128 (patience=30)
#     Fold 5: Best Epoch = 98, Val_R² = 0.9806
# Avg R² for this set of hyperparameters: 0.9708
#
# Testing Learning Rate: 0.005, Hidden Dim: 128, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 53 (patience=10)
#     Fold 1: Best Epoch = 43, Val_R² = 0.9650
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 110 (patience=10)
#     Fold 2: Best Epoch = 100, Val_R² = 0.9733
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 110 (patience=10)
#     Fold 3: Best Epoch = 100, Val_R² = 0.9599
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 89 (patience=10)
#     Fold 4: Best Epoch = 79, Val_R² = 0.9550
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 77 (patience=10)
#     Fold 5: Best Epoch = 67, Val_R² = 0.9788
# Avg R² for this set of hyperparameters: 0.9664
#
# Testing Learning Rate: 0.005, Hidden Dim: 128, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 98 (patience=20)
#     Fold 1: Best Epoch = 78, Val_R² = 0.9681
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 199 (patience=20)
#     Fold 2: Best Epoch = 179, Val_R² = 0.9730
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 360 (patience=20)
#     Fold 3: Best Epoch = 340, Val_R² = 0.9661
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 84 (patience=20)
#     Fold 4: Best Epoch = 64, Val_R² = 0.9576
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 242 (patience=20)
#     Fold 5: Best Epoch = 222, Val_R² = 0.9805
# Avg R² for this set of hyperparameters: 0.9691
#
# Testing Learning Rate: 0.005, Hidden Dim: 128, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 114 (patience=30)
#     Fold 1: Best Epoch = 84, Val_R² = 0.9682
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 117 (patience=30)
#     Fold 2: Best Epoch = 87, Val_R² = 0.9742
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 307 (patience=30)
#     Fold 3: Best Epoch = 277, Val_R² = 0.9663
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 326 (patience=30)
#     Fold 4: Best Epoch = 296, Val_R² = 0.9636
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 250 (patience=30)
#     Fold 5: Best Epoch = 220, Val_R² = 0.9804
# Avg R² for this set of hyperparameters: 0.9705
#
# Testing Learning Rate: 0.01, Hidden Dim: 32, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 53 (patience=10)
#     Fold 1: Best Epoch = 43, Val_R² = 0.9650
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 68 (patience=10)
#     Fold 2: Best Epoch = 58, Val_R² = 0.9721
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 90 (patience=10)
#     Fold 3: Best Epoch = 80, Val_R² = 0.9637
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 68 (patience=10)
#     Fold 4: Best Epoch = 58, Val_R² = 0.9539
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 69 (patience=10)
#     Fold 5: Best Epoch = 59, Val_R² = 0.9788
# Avg R² for this set of hyperparameters: 0.9667
#
# Testing Learning Rate: 0.01, Hidden Dim: 32, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 114 (patience=20)
#     Fold 1: Best Epoch = 94, Val_R² = 0.9666
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 78 (patience=20)
#     Fold 2: Best Epoch = 58, Val_R² = 0.9731
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 97 (patience=20)
#     Fold 3: Best Epoch = 77, Val_R² = 0.9631
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 103 (patience=20)
#     Fold 4: Best Epoch = 83, Val_R² = 0.9591
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 104 (patience=20)
#     Fold 5: Best Epoch = 84, Val_R² = 0.9804
# Avg R² for this set of hyperparameters: 0.9685
#
# Testing Learning Rate: 0.01, Hidden Dim: 32, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 207 (patience=30)
#     Fold 1: Best Epoch = 177, Val_R² = 0.9691
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 127 (patience=30)
#     Fold 2: Best Epoch = 97, Val_R² = 0.9744
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 240 (patience=30)
#     Fold 3: Best Epoch = 210, Val_R² = 0.9665
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 114 (patience=30)
#     Fold 4: Best Epoch = 84, Val_R² = 0.9613
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 278 (patience=30)
#     Fold 5: Best Epoch = 248, Val_R² = 0.9805
# Avg R² for this set of hyperparameters: 0.9703
#
# Testing Learning Rate: 0.01, Hidden Dim: 64, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 82 (patience=10)
#     Fold 1: Best Epoch = 72, Val_R² = 0.9672
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 92 (patience=10)
#     Fold 2: Best Epoch = 82, Val_R² = 0.9741
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 32 (patience=10)
#     Fold 3: Best Epoch = 22, Val_R² = 0.9427
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 64 (patience=10)
#     Fold 4: Best Epoch = 54, Val_R² = 0.9618
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 70 (patience=10)
#     Fold 5: Best Epoch = 60, Val_R² = 0.9778
# Avg R² for this set of hyperparameters: 0.9647
#
# Testing Learning Rate: 0.01, Hidden Dim: 64, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 110 (patience=20)
#     Fold 1: Best Epoch = 90, Val_R² = 0.9686
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 117 (patience=20)
#     Fold 2: Best Epoch = 97, Val_R² = 0.9731
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 96 (patience=20)
#     Fold 3: Best Epoch = 76, Val_R² = 0.9622
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 74 (patience=20)
#     Fold 4: Best Epoch = 54, Val_R² = 0.9598
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 107 (patience=20)
#     Fold 5: Best Epoch = 87, Val_R² = 0.9801
# Avg R² for this set of hyperparameters: 0.9688
#
# Testing Learning Rate: 0.01, Hidden Dim: 64, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 166 (patience=30)
#     Fold 1: Best Epoch = 136, Val_R² = 0.9691
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 171 (patience=30)
#     Fold 2: Best Epoch = 141, Val_R² = 0.9726
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 285 (patience=30)
#     Fold 3: Best Epoch = 255, Val_R² = 0.9656
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 88 (patience=30)
#     Fold 4: Best Epoch = 58, Val_R² = 0.9591
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 257 (patience=30)
#     Fold 5: Best Epoch = 227, Val_R² = 0.9795
# Avg R² for this set of hyperparameters: 0.9692
#
# Testing Learning Rate: 0.01, Hidden Dim: 128, Patience: 10
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 74 (patience=10)
#     Fold 1: Best Epoch = 64, Val_R² = 0.9670
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 78 (patience=10)
#     Fold 2: Best Epoch = 68, Val_R² = 0.9739
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 30 (patience=10)
#     Fold 3: Best Epoch = 20, Val_R² = 0.9441
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 57 (patience=10)
#     Fold 4: Best Epoch = 47, Val_R² = 0.9615
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 83 (patience=10)
#     Fold 5: Best Epoch = 73, Val_R² = 0.9797
# Avg R² for this set of hyperparameters: 0.9652
#
# Testing Learning Rate: 0.01, Hidden Dim: 128, Patience: 20
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 86 (patience=20)
#     Fold 1: Best Epoch = 66, Val_R² = 0.9676
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 105 (patience=20)
#     Fold 2: Best Epoch = 85, Val_R² = 0.9730
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 274 (patience=20)
#     Fold 3: Best Epoch = 254, Val_R² = 0.9664
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 64 (patience=20)
#     Fold 4: Best Epoch = 44, Val_R² = 0.9612
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 101 (patience=20)
#     Fold 5: Best Epoch = 81, Val_R² = 0.9793
# Avg R² for this set of hyperparameters: 0.9695
#
# Testing Learning Rate: 0.01, Hidden Dim: 128, Patience: 30
#   Fold 1 - Training...
#     Fold 1: Early stopping at epoch 236 (patience=30)
#     Fold 1: Best Epoch = 206, Val_R² = 0.9686
#   Fold 2 - Training...
#     Fold 2: Early stopping at epoch 101 (patience=30)
#     Fold 2: Best Epoch = 71, Val_R² = 0.9738
#   Fold 3 - Training...
#     Fold 3: Early stopping at epoch 268 (patience=30)
#     Fold 3: Best Epoch = 238, Val_R² = 0.9663
#   Fold 4 - Training...
#     Fold 4: Early stopping at epoch 69 (patience=30)
#     Fold 4: Best Epoch = 39, Val_R² = 0.9628
#   Fold 5 - Training...
#     Fold 5: Early stopping at epoch 106 (patience=30)
#     Fold 5: Best Epoch = 76, Val_R² = 0.9786
# Avg R² for this set of hyperparameters: 0.9700
#
# ====== LSTM Grid Search Completed ======
# Best Hyperparameters: Learning Rate = 0.005, Hidden Dim = 64, Epochs = 191
#
# ====== Training LSTM Run 1/10 ======
# Model 1 saved as final_LSTM_model_run_1.pth
# Run 1: Training Time = 0.38 s
# 2020 - RMSE: 2629.7948, MAE: 2251.9848, R²: 0.9694, NMAE: 0.0625, NRMSE: 0.0730
# 2021 - RMSE: 3045.9472, MAE: 2612.0129, R²: 0.9616, NMAE: 0.0711, NRMSE: 0.0829
# 2022 - RMSE: 2563.0281, MAE: 2224.4065, R²: 0.9703, NMAE: 0.0605, NRMSE: 0.0697
#
# ====== Training LSTM Run 2/10 ======
# Model 2 saved as final_LSTM_model_run_2.pth
# Run 2: Training Time = 0.39 s
# 2020 - RMSE: 2644.9410, MAE: 2250.6754, R²: 0.9690, NMAE: 0.0625, NRMSE: 0.0735
# 2021 - RMSE: 3099.5885, MAE: 2641.4572, R²: 0.9602, NMAE: 0.0719, NRMSE: 0.0844
# 2022 - RMSE: 2669.3431, MAE: 2264.4490, R²: 0.9678, NMAE: 0.0616, NRMSE: 0.0726
#
# ====== Training LSTM Run 3/10 ======
# Model 3 saved as final_LSTM_model_run_3.pth
# Run 3: Training Time = 0.39 s
# 2020 - RMSE: 2574.7881, MAE: 2224.5665, R²: 0.9706, NMAE: 0.0618, NRMSE: 0.0715
# 2021 - RMSE: 3069.6049, MAE: 2623.2256, R²: 0.9610, NMAE: 0.0714, NRMSE: 0.0836
# 2022 - RMSE: 2562.2025, MAE: 2164.3186, R²: 0.9704, NMAE: 0.0588, NRMSE: 0.0697
#
# ====== Training LSTM Run 4/10 ======
# Model 4 saved as final_LSTM_model_run_4.pth
# Run 4: Training Time = 0.38 s
# 2020 - RMSE: 2710.4562, MAE: 2274.1800, R²: 0.9674, NMAE: 0.0632, NRMSE: 0.0753
# 2021 - RMSE: 3194.6788, MAE: 2737.9429, R²: 0.9578, NMAE: 0.0745, NRMSE: 0.0870
# 2022 - RMSE: 2751.0309, MAE: 2304.6718, R²: 0.9658, NMAE: 0.0627, NRMSE: 0.0748
#
# ====== Training LSTM Run 5/10 ======
# Model 5 saved as final_LSTM_model_run_5.pth
# Run 5: Training Time = 0.38 s
# 2020 - RMSE: 2585.5353, MAE: 2230.8517, R²: 0.9704, NMAE: 0.0620, NRMSE: 0.0718
# 2021 - RMSE: 3099.9390, MAE: 2677.6801, R²: 0.9602, NMAE: 0.0729, NRMSE: 0.0844
# 2022 - RMSE: 2511.4175, MAE: 2139.4441, R²: 0.9715, NMAE: 0.0582, NRMSE: 0.0683
#
# ====== Training LSTM Run 6/10 ======
# Model 6 saved as final_LSTM_model_run_6.pth
# Run 6: Training Time = 0.37 s
# 2020 - RMSE: 2675.4891, MAE: 2299.3602, R²: 0.9683, NMAE: 0.0639, NRMSE: 0.0743
# 2021 - RMSE: 3141.4709, MAE: 2702.3000, R²: 0.9592, NMAE: 0.0736, NRMSE: 0.0855
# 2022 - RMSE: 2637.4735, MAE: 2150.8958, R²: 0.9686, NMAE: 0.0585, NRMSE: 0.0717
#
# ====== Training LSTM Run 7/10 ======
# Model 7 saved as final_LSTM_model_run_7.pth
# Run 7: Training Time = 0.38 s
# 2020 - RMSE: 2676.8576, MAE: 2326.4508, R²: 0.9682, NMAE: 0.0646, NRMSE: 0.0743
# 2021 - RMSE: 3140.6836, MAE: 2655.3730, R²: 0.9592, NMAE: 0.0723, NRMSE: 0.0855
# 2022 - RMSE: 2708.7844, MAE: 2202.9799, R²: 0.9669, NMAE: 0.0599, NRMSE: 0.0737
#
# ====== Training LSTM Run 8/10 ======
# Model 8 saved as final_LSTM_model_run_8.pth
# Run 8: Training Time = 0.44 s
# 2020 - RMSE: 2618.8512, MAE: 2231.8502, R²: 0.9696, NMAE: 0.0620, NRMSE: 0.0727
# 2021 - RMSE: 3044.0551, MAE: 2619.5143, R²: 0.9616, NMAE: 0.0713, NRMSE: 0.0829
# 2022 - RMSE: 2589.8427, MAE: 2227.4065, R²: 0.9697, NMAE: 0.0606, NRMSE: 0.0704
#
# ====== Training LSTM Run 9/10 ======
# Model 9 saved as final_LSTM_model_run_9.pth
# Run 9: Training Time = 0.47 s
# 2020 - RMSE: 2630.4176, MAE: 2269.7716, R²: 0.9693, NMAE: 0.0630, NRMSE: 0.0731
# 2021 - RMSE: 3070.6552, MAE: 2634.2219, R²: 0.9610, NMAE: 0.0717, NRMSE: 0.0836
# 2022 - RMSE: 2596.8461, MAE: 2194.3341, R²: 0.9695, NMAE: 0.0597, NRMSE: 0.0706
#
# ====== Training LSTM Run 10/10 ======
# Model 10 saved as final_LSTM_model_run_10.pth
# Run 10: Training Time = 0.45 s
# 2020 - RMSE: 2567.5036, MAE: 2179.9056, R²: 0.9708, NMAE: 0.0605, NRMSE: 0.0713
# 2021 - RMSE: 2987.3127, MAE: 2538.6564, R²: 0.9631, NMAE: 0.0691, NRMSE: 0.0813
# 2022 - RMSE: 2671.6616, MAE: 2321.9114, R²: 0.9678, NMAE: 0.0631, NRMSE: 0.0726
# Results saved to LSTM_results.csv
